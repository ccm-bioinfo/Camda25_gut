# %% [markdown]
# # GMHI development notebook

# %%
#Librerias que se utilizarán
import pandas as pd
import numpy as np
from sklearn.metrics import balanced_accuracy_score, f1_score
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import pickle

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Function to calculate: $f_H=\frac{p_{H,m}}{p_{N,m}}$, $f_N=\frac{p_{N,m}}{p_{H,m}}$ ,$d_H=p_{H,m}-p_{N,m}$ y $d_N=p_{N,m}-p_{H,m}$

# %%
def get_fH_fN_dH_dN(meta,tax):
    ######### Recibe los data frames de los metadatos y la taxonomia.
    
    #Se obtienen los id's de las muestras saludables identificadas en los metadatos y después 
    #observamos la taxonomia de las muestras saludables
    healthy_id = meta[meta['category']=='healthy']['sample']
    tax_healthy = tax[healthy_id]
    
    #Se obtienen los id's de muestras no saludables y despues se observa la taxonmia de estas muestras
    no_healthy_id = meta[meta['category']!='healthy']['sample']
    tax_no_healthy = tax[no_healthy_id]
    
    #Se obtienen todas las especies de todas las muestras
    species = tax.index
    
    #Definimos lower para establecer una cota y evitar divisiones entre 0
    lower=1e-05
    
    #Se crea un Data Frame que tendrá las metricas como columnas y a las especies como index
    metrics=pd.DataFrame(index=species,columns=['f_H','f_N','d_H','d_N'])
    
    #Este ciclo obtiene para cada especie m las prevalencias en las muestras saludables p_H y no saludables P_N
    #Posteriormente se  agregan f_H,f_N, d_H y d_N al data frame metric
    for specie in species:
        
        #Se localiza la especie en todas las muestras healthy y se obtiene su presencia absoluta
        specie_in_H=tax_healthy.loc[specie,:]
        abs_pres_H=len(specie_in_H[specie_in_H!=0])
        
        #Se localiza la especie en todas las muestras no-healthy y se obtiene su presencia absoluta
        specie_in_N=tax_no_healthy.loc[specie,:]
        abs_pres_N=len(specie_in_N[specie_in_N!=0])
        
        #Se obtiene PH y PN de la especie, tomando en cuenta que si el resultado es 0, entonces se intercambia por la cota 1e-05
        PH=np.divide(abs_pres_H,len(specie_in_H),out=np.asanyarray(lower),where=(abs_pres_H!=0))
        PN=np.divide(abs_pres_N,len(specie_in_N),out=np.asanyarray(lower),where=(abs_pres_N!=0))
        metrics.loc[specie,:]=[np.divide(PH,PN),np.divide(PN,PH),PH-PN,PN-PH]
    return metrics

######### Regresa un DataFrame en el que para cada especie se obtienen sus metricas f_H,f_N,d_H y d_N

# %%
def get_MH_MN(metrics,theta_f,theta_d):
    ######### Recibe el conjunto de metricas para cada especie y los parámetros de comparación
    
    
    #Se obtienen las especies beneficiosas que son mayores a los parametros theta_f y theta_d
    health_species_pass_theta_f=set(metrics[metrics['f_H']>=theta_f].index)
    health_species_pass_theta_d=set(metrics[metrics['d_H']>=theta_d].index)
    
    #Se obtienen las especies dañinas que son mayores a los parametros theta_f y theta_d
    no_health_species_pass_theta_f=set(metrics[metrics['f_N']>=theta_f].index)
    no_health_species_pass_theta_d=set(metrics[metrics['d_N']>=theta_d].index)
    
    #Se definen los conjuntos de las especies beneficiosas y dañinas que superan ambos parámetros
    MH=health_species_pass_theta_f & health_species_pass_theta_d
    MN=no_health_species_pass_theta_f & no_health_species_pass_theta_d
    
    # print('|MH|=', len(MH) )
    # print('|MN|=', len(MN))        
    return MH,MN

######### Regresa los conjuntos de especies identificadas beneficiosas MH y dañinas MN, de acuerdo a los parámetros

# %% [markdown]
# This function calculates $\Psi_{{M_H},i}=\frac{R_{{M_H},i}}{|M_H|} \sum_{j\in I_{M_H}}|n_{j,i}\ln(n_{j,i})|$ or $\Psi_{{M_N},i}$ for sample $i$.
# Here:
# - $R_{{M_H},i}$ is the species richness of $M_H$ in sample $i$.</li>
# - $|M_H|$ is the size of the set $M_H$.</li>
# - $I_{M_H}$ is the index set of $M_H$.</li>
# - $n_{j,i}$ is the relative abundance of species $j$ in sample $i$.</li>
#
# $\Psi_{{M_N},i}$ for sample $i$ is calculated analogously.

# %%
def get_Psi(set_M,sample):
    ######### Recibe el conjunto M_H o M_N y la muestra con la presencia relativa de cada especie
    
    
    #M_in_sample es el conjunto M_H o M_N intersección las especies presentes en la muestra i
    M_in_sample=set(sample[sample!=0].index) & set_M
    
    #Se calcula la R_M
    R_M_sample=np.divide(len(M_in_sample),len(set_M))
    
    #Se obtiene el array n, que contiene las abundanicas relativas de las especies presentes de M en la muestra i
    #Posteriormente se calcula el logaritmo y la suma
    n=sample[sample!=0][list(M_in_sample)]
    log_n=np.log(n)
    sum_nlnn=np.sum(n*log_n)
    
    #Finalmente se recupera Psi para la muestra i y el conjunto M
    Psi=np.divide(R_M_sample,len(set_M))*np.absolute(sum_nlnn)
    
    #Se evita que el caso Psi sea igual a 0 para evitar división entre 0 en la siguiente función. 
    if Psi==0:
        Psi=1e-05
    return Psi

######### Regresa el número Psi asociado a la muestra i y  al conjunto M_H o M_N.

# %%
def get_all_GMHI(tax,MH,MN):
    ######### Se ingresa la taxonomia, el conjunto de especies MH y MN.
    

    #Se crea la variable GMHI, una serie de pandas que tiene como indice el nombre de la muestra y como información su indice GMHI.
    #Esta serie se llenará con un ciclo for, que recorre todas las especies
    samples=tax.columns 
    GMHI=pd.Series(index=samples,name='GMHI',dtype='float64')
    for sample in samples:
        
        #Se obtiene Psi_MH y Psi_MN con la función get_Psi
        Psi_MH=get_Psi(MH,tax[sample])
        Psi_MN=get_Psi(MN,tax[sample])
        
        #Se hace el cociente y se evalua en el logaritmo base 10. Posteriormente se agrega la información a la serie GMHI
        GMHI_sample=np.log10(np.divide(Psi_MH,Psi_MN))
        GMHI[sample]=GMHI_sample
        
    return GMHI 

######### Se regresa la serie con el índice GMHI de cada muestra

# %%
def get_accuracy(GMHI,meta):    
    return balanced_accuracy_score(['Unhealthy' if x != 'healthy' else 'Healthy' for x in meta['category']], ['Unhealthy' if x < 0 else 'Healthy' for x in list(GMHI)])

# %%
def get_accuracy2(GMHI,meta):    
    return f1_score([0 if x != 'healthy' else 1 for x in meta['category']], [0 if x < 0 else 1 for x in list(GMHI)], pos_label = 0)

# %%
meta = pd.read_csv('../../DataSets/CAMDA_2025/metadata.txt', sep="\t")
tax=pd.read_csv('../../DataSets/CAMDA_2025/taxa.txt',sep='\t',index_col=0)
metrics=get_fH_fN_dH_dN(meta,tax)

# %%
theta_f = 1.4
# theta_d = 0.1 # Esto lo tengo que relajar porque pone en mucha desventaja especies poco abundantes
theta_d = 0.0001
MH,MN=get_MH_MN(metrics,theta_f,theta_d)

# %%
MH_test=pd.read_csv('../../DataSets/INDEX/GMHI/MH_species.txt', sep="\t", index_col=0)
MN_test=pd.read_csv('../../DataSets/INDEX/GMHI/MN_species.txt', sep='\t',index_col=0)
MH_estandar=set()
for i in MH_test.index:
    MH_estandar.add(i[3:])
MN_estandar=set()    
for i in MN_test.index:
    MN_estandar.add(i[3:])

# %%
H=MH_estandar.union(MH)
N=MN_estandar.union(MN)

# %%
GMHI=get_all_GMHI(tax,MH_estandar,MN_estandar)
    
accuracy=get_accuracy(GMHI,meta)

print('El accuracy obtenido es de', accuracy*100 ,'%')
GMHI
# Out:
# El accuracy obtenido es de 48.98468319169913 %
# train_0      -2.499385
# train_1       1.327050
# train_2       0.911783
# train_3       0.527261
# train_4       2.318180
#                 ...
# train_4393   -1.240998
# train_4394   -1.763727
# train_4395    0.293090
# train_4396   -3.290298
# train_4397   -2.388021
# Name: GMHI, Length: 4398, dtype: float64

# %%
#Se calcula el GMHI de cada muestra y también se obtiene el data frame de los metadatos
GMHI=get_all_GMHI(tax,MH,MN)
    
accuracy=get_accuracy(GMHI,meta)

print('El accuracy obtenido es de', accuracy*100 ,'%')
GMHI
# Out:
# El accuracy obtenido es de 61.23903517246176 %
# train_0       0.752712
# train_1       0.116071
# train_2       0.911509
# train_3       0.468087
# train_4       1.142087
#                 ...
# train_4393   -0.113986
# train_4394    0.985035
# train_4395    2.086687
# train_4396    0.652616
# train_4397   -0.489720
# Name: GMHI, Length: 4398, dtype: float64

# %%
#Se calcula el GMHI de cada muestra y también se obtiene el data frame de los metadatos
GMHI=get_all_GMHI(tax,H,N)
    
accuracy=get_accuracy(GMHI,meta)

print('El accuracy obtenido es de', accuracy*100 ,'%')
GMHI
# Out:
# El accuracy obtenido es de 59.30296543036224 %
# train_0      -0.387869
# train_1      -1.267850
# train_2      -0.096878
# train_3      -0.388359
# train_4       1.159667
#                 ...
# train_4393    0.834604
# train_4394   -0.993917
# train_4395    0.241520
# train_4396   -1.054785
# train_4397   -0.688152
# Name: GMHI, Length: 4398, dtype: float64

# %%
# meta = meta[meta['category'].isin(['healthy', 'CRC', 'adenoma', 'IBD', 'UC', 'CD', 'acute_diarrhoea', 'few_polyps'])]
# meta = meta[meta['category'].isin(["healthy", "ACVD", "CAD","HF","CAD:T2D","HF:CAD","HF:CAD:T2D"])]
meta = meta[meta['category'].isin(["healthy", "PD","BD","schizophrenia", "IGT:MS", "ME/CFS"])]
# metabolic_conditions = [
#         "T2D",
#         "IGT",
#         "metabolic_syndrome",
#         "hypercholesterolemia",
#         "adenoma;hypercholesterolemia",
#         "T2D:adenoma",
#         "CRC:hypercholesterolemia",
#         "healthy"
#     ]


# meta = meta[meta['category'].isin(metabolic_conditions)]
meta.reset_index(drop=True, inplace=True)
data = tax[list(meta['sample'])]

# %%
data = tax

# %%
labels = []
for sample in data.T.index:
    labels.append(meta[meta['sample'] == sample]['category'].iloc[0])
labels = ['Healthy' if x == 'healthy' else 'Unhealthy' for x in labels]
labels = pd.DataFrame(labels)

# %%
meta
# Out:
#            category         cohort  category_binary      GMHI     hiPCA  \
# 0           healthy  BedarfJR_2017                1 -3.040711 -2.230508
# 1           healthy  BedarfJR_2017                1  2.815237 -0.255368
# 2           healthy  BedarfJR_2017                1  0.900492 -0.746855
# 3           healthy  BedarfJR_2017                1 -0.464491 -1.179001
# 4           healthy  BedarfJR_2017                1  1.615869 -0.672061
# ...             ...            ...              ...       ...       ...
# 4393  schizophrenia      ZhuF_2020                0 -1.353887 -0.436142
# 4394  schizophrenia      ZhuF_2020                0 -3.017436 -1.864214
# 4395  schizophrenia      ZhuF_2020                0 -0.545163 -1.790557
# 4396  schizophrenia      ZhuF_2020                0 -3.686342 -1.776473
# 4397  schizophrenia      ZhuF_2020                0 -2.909410 -1.063560
#
#       Shannon_Entropy  Shannon_Entropy_on_Functions      sample
# 0            2.712028                      5.090256     train_0
# 1            2.843911                      4.680161     train_1
# 2            3.213241                      4.994824     train_2
# 3            3.359700                      5.218929     train_3
# 4            3.397204                      5.096859     train_4
# ...               ...                           ...         ...
# 4393         1.267090                      4.773954  train_4393
# 4394         2.581850                      5.102139  train_4394
# 4395         2.539637                      5.117396  train_4395
# 4396         2.405504                      5.228193  train_4396
# 4397         2.193468                      5.434235  train_4397
#
# [4398 rows x 8 columns]

# %%
data
# Out:
#                                  train_0  train_1   train_2   train_3  \
# #sample-id
# Bacteroides_vulgatus            11.66601  2.73563  12.44949  10.04475
# Roseburia_faecis                 0.00000  0.00000   0.00000   0.24374
# Ruminococcus_gnavus              0.59774  0.00000   0.00000   0.00000
# Roseburia_intestinalis          17.31798  0.18250   5.60477   3.53356
# Blautia_wexlerae                 0.00000  0.03673   0.03077   0.00000
# ...                                  ...      ...       ...       ...
# Geobacillus_stearothermophilus   0.00000  0.00000   0.00000   0.00000
# Corynebacterium_falsenii         0.00000  0.00000   0.00000   0.00000
# Mycobacterium_avium              0.00000  0.00000   0.00000   0.00000
# Oligella_ureolytica              0.00000  0.00000   0.00000   0.00000
# Paenibacillus_sp_7884_2          0.00000  0.00000   0.00000   0.00000
#
#                                 train_4  train_5  train_6  train_7   train_8  \
# #sample-id
# Bacteroides_vulgatus            7.68169  7.41403  2.10612  0.43836   0.67724
# Roseburia_faecis                4.10589  1.37947  0.78747  3.13218  10.80664
# Ruminococcus_gnavus             0.00000  0.00000  0.00000  0.00000   0.00000
# Roseburia_intestinalis          0.50953  5.28531  0.00000  5.61191   0.26558
# Blautia_wexlerae                0.00914  0.26341  0.00000  0.00000   0.90261
# ...                                 ...      ...      ...      ...       ...
# Geobacillus_stearothermophilus  0.00000  0.00000  0.00000  0.00000   0.00000
# Corynebacterium_falsenii        0.00000  0.00000  0.00000  0.00000   0.00000
# Mycobacterium_avium             0.00000  0.00000  0.00000  0.00000   0.00000
# Oligella_ureolytica             0.00000  0.00000  0.00000  0.00000   0.00000
# Paenibacillus_sp_7884_2         0.00000  0.00000  0.00000  0.00000   0.00000
#
#                                 train_9  ...  train_4388  train_4389  \
# #sample-id                               ...
# Bacteroides_vulgatus            2.27049  ...    16.16002    84.97335
# Roseburia_faecis                1.06868  ...     0.66276     0.00827
# Ruminococcus_gnavus             0.00000  ...     0.00000     0.60347
# Roseburia_intestinalis          0.00160  ...     1.17488     0.00565
# Blautia_wexlerae                0.00000  ...     0.04031     0.30255
# ...                                 ...  ...         ...         ...
# Geobacillus_stearothermophilus  0.00000  ...     0.00000     0.00000
# Corynebacterium_falsenii        0.00000  ...     0.00000     0.00000
# Mycobacterium_avium             0.00000  ...     0.00000     0.00000
# Oligella_ureolytica             0.00000  ...     0.00000     0.00000
# Paenibacillus_sp_7884_2         0.00000  ...     0.00000     0.00000
#
#                                 train_4390  train_4391  train_4392  \
# #sample-id
# Bacteroides_vulgatus               5.81158     0.18158    10.80066
# Roseburia_faecis                   0.03672     4.94094     0.84947
# Ruminococcus_gnavus                0.04162     0.30747     0.10444
# Roseburia_intestinalis             0.23012     0.92168     0.08458
# Blautia_wexlerae                   0.02733     0.02141     0.06950
# ...                                    ...         ...         ...
# Geobacillus_stearothermophilus     0.00000     0.00000     0.00000
# Corynebacterium_falsenii           0.00000     0.00000     0.00000
# Mycobacterium_avium                0.00000     0.00000     0.00000
# Oligella_ureolytica                0.00000     0.01006     0.00000
# Paenibacillus_sp_7884_2            0.00000     0.00000     0.00000
#
#                                 train_4393  train_4394  train_4395  \
# #sample-id
# Bacteroides_vulgatus               0.12498     7.38215     9.87256
# Roseburia_faecis                   0.29030     0.02743     0.01955
# Ruminococcus_gnavus                0.00000     0.00172     0.29646
# Roseburia_intestinalis             0.28876     1.18431     0.00395
# Blautia_wexlerae                   0.00489     0.04333     0.03602
# ...                                    ...         ...         ...
# Geobacillus_stearothermophilus     0.00000     0.00000     0.00000
# Corynebacterium_falsenii           0.00000     0.00000     0.00000
# Mycobacterium_avium                0.00000     0.00000     0.00000
# Oligella_ureolytica                0.00000     0.00000     0.00000
# Paenibacillus_sp_7884_2            0.00000     0.00000     0.00000
#
#                                 train_4396  train_4397
# #sample-id
# Bacteroides_vulgatus              34.63441    11.67750
# Roseburia_faecis                   0.00000     0.00964
# Ruminococcus_gnavus                2.59479     0.60770
# Roseburia_intestinalis             0.00000     5.36433
# Blautia_wexlerae                   0.00318     0.04264
# ...                                    ...         ...
# Geobacillus_stearothermophilus     0.00000     0.00000
# Corynebacterium_falsenii           0.00000     0.00000
# Mycobacterium_avium                0.00000     0.00000
# Oligella_ureolytica                0.00000     0.00000
# Paenibacillus_sp_7884_2            0.01945     0.00000
#
# [1211 rows x 4398 columns]

# %%
metrics=get_fH_fN_dH_dN(meta, data)

# %%
MH,MN=get_MH_MN(metrics,theta_f,theta_d)

# %%
MH
# Out:
# {'Acinetobacter_parvus',
#  'Aerococcus_urinaeequi',
#  'Aerococcus_viridans',
#  'Aeromonas_caviae',
#  'Bacillus_cereus_group',
#  'Bacillus_sp_FJAT_27916',
#  'Bacteroides_caecimuris',
#  'Bacteroides_faecichinchillae',
#  'Bacteroides_intestinalis',
#  'Bacteroides_oleiciplenus',
#  'Bacteroides_pectinophilus',
#  'Bacteroides_sartorii',
#  'Bacteroides_sp_OM05_12',
#  'Bacteroidetes_bacterium_oral_taxon_272',
#  'Bifidobacterium_kashiwanohense',
#  'Bifidobacterium_ruminantium',
#  'Bosea_vaviloviae',
#  'Candidatus_Gastranaerophilales_bacterium_HUM_9',
#  'Candidatus_Stoquefichus_sp_KLE1796',
#  'Carnobacterium_maltaromaticum',
#  'Citrobacter_koseri',
#  'Citrobacter_portucalensis',
#  'Clostridium_neonatale',
#  'Clostridium_sp_CAG_299',
#  'Clostridium_sp_chh4_2',
#  'Comamonas_kerstersii',
#  'Coprobacter_sp',
#  'Corynebacterium_casei',
#  'Corynebacterium_glutamicum',
#  'Corynebacterium_variabile',
#  'Desulfovibrio_fairfieldensis',
#  'Dialister_sp_CAG_357',
#  'Dysgonomonas_gadei',
#  'Dysgonomonas_sp_37_18',
#  'Elizabethkingia_anophelis',
#  'Enterobacter_soli',
#  'Enterococcus_canis',
#  'Enterococcus_malodoratus',
#  'Escherichia_fergusonii',
#  'Eubacterium_sp_CAG_786',
#  'Flavonifractor_sp_An82',
#  'Geobacillus_stearothermophilus',
#  'Helicobacter_pullorum',
#  'Hungatella_effluvii',
#  'Kluyvera_ascorbata',
#  'Kluyvera_cryocrescens',
#  'Kocuria_indica',
#  'Kosakonia_sacchari',
#  'Lactobacillus_acidipiscis',
#  'Lactobacillus_algidus',
#  'Lactobacillus_mindensis',
#  'Lactobacillus_pentosus',
#  'Lactococcus_piscium',
#  'Lactococcus_raffinolactis',
#  'Leuconostoc_citreum',
#  'Leuconostoc_gelidum',
#  'Leuconostoc_suionicum',
#  'Megamonas_rupellensis',
#  'Megasphaera_hexanoica',
#  'Methanosphaera_stadtmanae',
#  'Mycolicibacterium_obuense',
#  'Mycoplasma_bovis',
#  'Pantoea_dispersa',
#  'Parabacteroides_chinchillae',
#  'Phytobacter_ursingii',
#  'Prevotella_sp_CAG_1058',
#  'Prevotella_sp_CAG_924',
#  'Pseudoalteromonas_tetraodonis',
#  'Pseudomonas_fragi',
#  'Pseudomonas_lundensis',
#  'Pyrococcus_yayanosii',
#  'Roseburia_sp_CAG_303',
#  'Ruminococcus_champanellensis',
#  'Ruminococcus_sp_CAG_579',
#  'Ruminococcus_sp_CAG_624',
#  'Staphylococcus_capitis',
#  'Staphylococcus_hominis',
#  'Staphylococcus_kloosii',
#  'Staphylococcus_sciuri',
#  'Staphylococcus_xylosus',
#  'Streptococcus_equinus',
#  'Streptococcus_pyogenes',
#  'Terrisporobacter_othiniensis',
#  'Vibrio_fluvialis'}

# %%
MN
# Out:
# {'Abiotrophia_defectiva',
#  'Abiotrophia_sp_HMSC24B09',
#  'Acidaminococcus_fermentans',
#  'Actinobaculum_sp_oral_taxon_183',
#  'Actinomyces_cardiffensis',
#  'Actinomyces_graevenitzii',
#  'Actinomyces_hongkongensis',
#  'Actinomyces_johnsonii',
#  'Actinomyces_massiliensis',
#  'Actinomyces_naeslundii',
#  'Actinomyces_oris',
#  'Actinomyces_sp_HMSC035G02',
#  'Actinomyces_sp_HPA0247',
#  'Actinomyces_sp_S6_Spd3',
#  'Actinomyces_sp_oral_taxon_180',
#  'Actinomyces_sp_oral_taxon_181',
#  'Actinomyces_sp_oral_taxon_414',
#  'Actinomyces_sp_oral_taxon_897',
#  'Actinomyces_turicensis',
#  'Actinomyces_viscosus',
#  'Aeriscardovia_aeriphila',
#  'Aeromonas_allosaccharophila',
#  'Aeromonas_hydrophila',
#  'Aggregatibacter_segnis',
#  'Aggregatibacter_sp_oral_taxon_458',
#  'Alistipes_sp_An66',
#  'Alistipes_sp_CHKCI003',
#  'Alloprevotella_rava',
#  'Alloprevotella_tannerae',
#  'Alloscardovia_omnicolens',
#  'Anaerococcus_vaginalis',
#  'Anaeroglobus_geminatus',
#  'Arcobacter_butzleri',
#  'Atlantibacter_hermannii',
#  'Atopobium_deltae',
#  'Atopobium_minutum',
#  'Atopobium_parvulum',
#  'Atopobium_rimae',
#  'Atopobium_vaginae',
#  'Bacteroides_heparinolyticus',
#  'Bacteroides_salanitronis',
#  'Bacteroides_sp_CAG_530',
#  'Bacteroides_sp_CAG_633',
#  'Bacteroides_sp_CAG_661',
#  'Bacteroides_sp_CAG_927',
#  'Bifidobacterium_gallinarum',
#  'Bifidobacterium_moukalabense',
#  'Bifidobacterium_pseudolongum',
#  'Bifidobacterium_pullorum',
#  'Bifidobacterium_saeculare',
#  'Brachyspira_pilosicoli',
#  'Bulleidia_extructa',
#  'Campylobacter_coli',
#  'Campylobacter_concisus',
#  'Campylobacter_curvus',
#  'Campylobacter_gracilis',
#  'Campylobacter_mucosalis',
#  'Campylobacter_rectus',
#  'Campylobacter_showae',
#  'Campylobacter_ureolyticus',
#  'Candida_albicans',
#  'Candidatus_Methanomassiliicoccus_intestinalis',
#  'Cardiobacterium_hominis',
#  'Cardiobacterium_valvarum',
#  'Centipeda_periodontii',
#  'Citrobacter_amalonaticus',
#  'Citrobacter_farmeri',
#  'Citrobacter_sp_MGH106',
#  'Clostridioides_difficile',
#  'Clostridium_baratii',
#  'Clostridium_cadaveris',
#  'Clostridium_hylemonae',
#  'Clostridium_methylpentosum',
#  'Clostridium_scindens',
#  'Clostridium_sp_7_2_43FAA',
#  'Clostridium_sp_CAG_964',
#  'Clostridium_sp_D5',
#  'Clostridium_sp_MSTE9',
#  'Clostridium_sp_SY8519',
#  'Clostridium_ventriculi',
#  'Corynebacterium_accolens',
#  'Corynebacterium_durum',
#  'Corynebacterium_matruchotii',
#  'Criibacterium_bergeronii',
#  'Denitrobacterium_detoxificans',
#  'Desulfovibrionaceae_bacterium',
#  'Dialister_micraerophilus',
#  'Dialister_pneumosintes',
#  'Edwardsiella_tarda',
#  'Eggerthia_catenaformis',
#  'Eikenella_corrodens',
#  'Eisenbergiella_tayi',
#  'Enterococcus_avium',
#  'Enterococcus_casseliflavus',
#  'Enterococcus_durans',
#  'Enterococcus_faecalis',
#  'Enterococcus_gallinarum',
#  'Enterococcus_hirae',
#  'Eubacterium_brachy',
#  'Eubacterium_callanderi',
#  'Eubacterium_coprostanoligenes',
#  'Eubacterium_infirmum',
#  'Eubacterium_limosum',
#  'Eubacterium_nodatum',
#  'Eubacterium_saphenum',
#  'Eubacterium_sp_68_3_10',
#  'Eubacterium_sp_An11',
#  'Facklamia_hominis',
#  'Filifactor_alocis',
#  'Finegoldia_magna',
#  'Firmicutes_bacterium_CAG_424',
#  'Firmicutes_bacterium_CAG_791',
#  'Firmicutes_bacterium_CAG_94',
#  'Flavobacterium_sp_FEMGT703F',
#  'Fusobacterium_equinum',
#  'Fusobacterium_gonidiaformans',
#  'Fusobacterium_hwasookii',
#  'Fusobacterium_naviforme',
#  'Fusobacterium_necrophorum',
#  'Fusobacterium_nucleatum',
#  'Fusobacterium_periodonticum',
#  'Fusobacterium_sp_oral_taxon_370',
#  'Gemella_asaccharolytica',
#  'Gemella_bergeri',
#  'Gemella_haemolysans',
#  'Gemella_morbillorum',
#  'Gemmiger_sp_An50',
#  'Giardia_intestinalis',
#  'Granulicatella_adiacens',
#  'Granulicatella_elegans',
#  'Haemophilus_haemolyticus',
#  'Haemophilus_influenzae',
#  'Haemophilus_parahaemolyticus',
#  'Haemophilus_paraphrohaemolyticus',
#  'Haemophilus_quentini',
#  'Hafnia_alvei',
#  'Harryflintia_acetispora',
#  'Helicobacter_pylori',
#  'Lachnoanaerobaculum_saburreum',
#  'Lachnoclostridium_sp_An118',
#  'Lachnoclostridium_sp_An131',
#  'Lachnoclostridium_sp_An196',
#  'Lachnoclostridium_sp_An298',
#  'Lactobacillus_amylovorus',
#  'Lactobacillus_animalis',
#  'Lactobacillus_antri',
#  'Lactobacillus_brevis',
#  'Lactobacillus_crispatus',
#  'Lactobacillus_curvatus',
#  'Lactobacillus_delbrueckii',
#  'Lactobacillus_equicursoris',
#  'Lactobacillus_farciminis',
#  'Lactobacillus_fermentum',
#  'Lactobacillus_fuchuensis',
#  'Lactobacillus_gallinarum',
#  'Lactobacillus_gasseri',
#  'Lactobacillus_gastricus',
#  'Lactobacillus_helveticus',
#  'Lactobacillus_johnsonii',
#  'Lactobacillus_kalixensis',
#  'Lactobacillus_mucosae',
#  'Lactobacillus_oris',
#  'Lactobacillus_panis',
#  'Lactobacillus_paragasseri',
#  'Lactobacillus_plantarum',
#  'Lactobacillus_reuteri',
#  'Lactobacillus_salivarius',
#  'Lactobacillus_vaginalis',
#  'Lactobacillus_versmoldensis',
#  'Lawsonella_clevelandensis',
#  'Leptotrichia_hofstadii',
#  'Leptotrichia_sp_oral_taxon_212',
#  'Leptotrichia_sp_oral_taxon_215',
#  'Leptotrichia_sp_oral_taxon_225',
#  'Leptotrichia_sp_oral_taxon_498',
#  'Leptotrichia_sp_oral_taxon_879',
#  'Leptotrichia_wadei',
#  'Leuconostoc_carnosum',
#  'Mageeibacillus_indolicus',
#  'Marvinbryantia_formatexigens',
#  'Megasphaera_micronuciformis',
#  'Megasphaera_stantonii',
#  'Melissococcus_sp_OM08_11BH',
#  'Methanobrevibacter_arboriphilus',
#  'Mitsuokella_sp_oral_taxon_131',
#  'Mogibacterium_pumilum',
#  'Mogibacterium_timidum',
#  'Moraxella_catarrhalis',
#  'Morganella_morganii',
#  'Morococcus_cerebrosus',
#  'Muribaculum_intestinale',
#  'Negativicoccus_succinicivorans',
#  'Neisseria_elongata',
#  'Neisseria_flavescens',
#  'Neisseria_mucosa',
#  'Neisseria_perflava',
#  'Neisseria_sicca',
#  'Neisseria_sp_oral_taxon_014',
#  'Neisseria_subflava',
#  'Olsenella_profusa',
#  'Olsenella_uli',
#  'Oribacterium_asaccharolyticum',
#  'Oribacterium_parvum',
#  'Oribacterium_sinus',
#  'Oribacterium_sp_oral_taxon_078',
#  'Paeniclostridium_sordellii',
#  'Paraclostridium_bifermentans',
#  'Parascardovia_denticolens',
#  'Parvimonas_micra',
#  'Parvimonas_sp_oral_taxon_110',
#  'Parvimonas_sp_oral_taxon_393',
#  'Pediococcus_acidilactici',
#  'Peptococcus_niger',
#  'Peptoniphilus_coxii',
#  'Peptoniphilus_grossensis',
#  'Peptoniphilus_harei',
#  'Peptoniphilus_lacrimalis',
#  'Peptoniphilus_sp_HMSC062D09',
#  'Peptostreptococcus_anaerobius',
#  'Peptostreptococcus_sp_MV1',
#  'Peptostreptococcus_stomatis',
#  'Phascolarctobacterium_sp',
#  'Plesiomonas_shigelloides',
#  'Pluralibacter_gergoviae',
#  'Porphyromonas_asaccharolytica',
#  'Porphyromonas_endodontalis',
#  'Porphyromonas_uenonis',
#  'Prevotella_bergensis',
#  'Prevotella_buccae',
#  'Prevotella_dentalis',
#  'Prevotella_denticola',
#  'Prevotella_histicola',
#  'Prevotella_intermedia',
#  'Prevotella_jejuni',
#  'Prevotella_melaninogenica',
#  'Prevotella_multiformis',
#  'Prevotella_multisaccharivorax',
#  'Prevotella_nigrescens',
#  'Prevotella_oris',
#  'Prevotella_oulorum',
#  'Prevotella_pallens',
#  'Prevotella_salivae',
#  'Prevotella_scopos',
#  'Prevotella_sp_885',
#  'Prevotella_sp_CAG_1092',
#  'Prevotella_sp_CAG_1320',
#  'Prevotella_sp_CAG_617',
#  'Prevotella_sp_CAG_755',
#  'Prevotella_sp_CAG_873',
#  'Prevotella_sp_F0091',
#  'Prevotella_sp_S7_1_8',
#  'Prevotella_sp_oral_taxon_306',
#  'Prevotella_sp_oral_taxon_376',
#  'Prevotella_sp_oral_taxon_473',
#  'Prevotella_veroralis',
#  'Propionibacterium_acidifaciens',
#  'Propionibacterium_freudenreichii',
#  'Proteus_hauseri',
#  'Proteus_vulgaris',
#  'Providencia_rettgeri',
#  'Pseudomonas_aeruginosa_group',
#  'Pseudomonas_fluorescens_group',
#  'Pseudomonas_yamanorum',
#  'Pseudopropionibacterium_propionicum',
#  'Pseudoramibacter_alactolyticus',
#  'Pyramidobacter_sp_C12_8',
#  'Raoultella_ornithinolytica',
#  'Raoultella_terrigena',
#  'Rhodococcus_erythropolis',
#  'Rhodococcus_qingshengii',
#  'Robinsoniella_sp_RHS',
#  'Rothia_aeria',
#  'Rothia_dentocariosa',
#  'Saccharomyces_cerevisiae',
#  'Scardovia_inopinata',
#  'Scardovia_wiggsiae',
#  'Selenomonas_noxia',
#  'Selenomonas_sp_FOBRC6',
#  'Selenomonas_sp_oral_taxon_126',
#  'Selenomonas_sp_oral_taxon_138',
#  'Selenomonas_sp_oral_taxon_920',
#  'Selenomonas_sputigena',
#  'Shuttleworthia_satelles',
#  'Slackia_exigua',
#  'Slackia_isoflavoniconvertens',
#  'Solobacterium_moorei',
#  'Staphylococcus_aureus',
#  'Stomatobaculum_longum',
#  'Streptococcus_anginosus_group',
#  'Streptococcus_cristatus',
#  'Streptococcus_gallolyticus',
#  'Streptococcus_infantarius',
#  'Streptococcus_lutetiensis',
#  'Streptococcus_macedonicus',
#  'Streptococcus_milleri',
#  'Streptococcus_mutans',
#  'Streptococcus_pasteurianus',
#  'Streptococcus_peroris',
#  'Streptococcus_pneumoniae',
#  'Streptococcus_pseudopneumoniae',
#  'Streptococcus_sinensis',
#  'Streptococcus_sobrinus',
#  'Streptococcus_sp_F0442',
#  'Streptococcus_sp_HMSC034E03',
#  'Streptococcus_sp_HMSC070B10',
#  'Streptococcus_sp_HMSC071D03',
#  'Streptococcus_sp_M334',
#  'Streptococcus_sp_NLAE_zl_C503',
#  'Streptococcus_sp_oral_taxon_058',
#  'Streptococcus_vestibularis',
#  'Streptococcus_viridans',
#  'Subdoligranulum_variabile',
#  'Treponema_denticola',
#  'Treponema_maltophilum',
#  'Treponema_medium',
#  'Treponema_socranskii',
#  'Treponema_succinifaciens',
#  'Varibaculum_cambriense',
#  'Variovorax_paradoxus',
#  'Veillonella_denticariosi',
#  'Veillonella_rodentium',
#  'Veillonella_seminalis',
#  'Vibrio_cholerae',
#  'Weissella_viridescens'}

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

evaluations = []
indexes = []
# Loop over each fold
for fold, (train_index, test_index) in enumerate(skf.split(data.T, labels)):
    # model_name = f'camda_pathways_fold{fold+1}'
    X_train, X_test = data.T.iloc[train_index], data.T.iloc[test_index]
    y_train, y_test = meta.iloc[train_index], meta.iloc[test_index]

    print(f"Fold {fold + 1}")
    
    metrics=get_fH_fN_dH_dN(y_train,X_train.T)
    # print(metrics)
    MH,MN=get_MH_MN(metrics,theta_f,theta_d)
    # print(MH)
    # print('.......')
    # print(MN)
    GMHI=get_all_GMHI(X_test.T,MH,MN)
    indexes.append(GMHI)
    
    accuracy=get_accuracy2(GMHI,y_test)
    # healthy_sub = [x for x in X_train.index if x in healthy]
    # nonhealthy_sub = [x for x in X_train.index if x in non_healthy]
    print(f'F1_score: {accuracy}')
    evaluations.append(accuracy)
# Out:
# Fold 1
# F1_score: 0.15527950310559005
# Fold 2
# F1_score: 0.16
# Fold 3
# F1_score: 0.16
# Fold 4
# F1_score: 0.13855421686746988
# Fold 5
# F1_score: 0.1373134328358209

# %%
GMHI_tax = pd.concat(indexes)

# %%
GMHI_tax.to_csv('GMHI_2025_tax_PC.csv')

# %%
GMHI_tax
# Out:
# train_5       1.027441
# train_72      0.602550
# train_81      0.134685
# train_200     1.052856
# train_203     1.344975
#                 ...
# train_4370    3.145617
# train_4373    4.684258
# train_4378    1.890247
# train_4380    1.766152
# train_4390    0.762429
# Name: GMHI, Length: 2412, dtype: float64

# %%
pathways = pd.read_csv('../../DataSets/CAMDA_2025/pathways.txt', sep = '\t', index_col = 0)

# %%
# meta = meta[meta['category'].isin(['healthy', 'CRC', 'adenoma', 'IBD', 'UC', 'CD', 'acute_diarrhoea', 'few_polyps'])]
# meta.reset_index(drop=True, inplace=True)
data = pathways[list(meta['sample'])]

# %%
# data = pathways

# %%
labels = []
for sample in data.T.index:
    labels.append(meta[meta['sample'] == sample]['category'].iloc[0])

labels = pd.DataFrame(labels)

# %%
data
# Out:
#                                                      train_0   train_1  \
# sample-id
# PWY-5686:_UMP_biosynthesis                          0.000058  0.000059
# PWY-6151:_S-adenosyl-L-methionine_cycle_I           0.000040  0.000057
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...  0.000062  0.000062
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...  0.000062  0.000085
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...  0.000062  0.000045
# ...                                                      ...       ...
# PWY-5655:_L-tryptophan_degradation_IX               0.000000  0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)   0.000000  0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis            0.000000  0.000000
# PWY-7626:_bacilysin_biosynthesis                    0.000000  0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)      0.000000  0.000000
#
#                                                      train_2   train_3  \
# sample-id
# PWY-5686:_UMP_biosynthesis                          0.000179  0.000146
# PWY-6151:_S-adenosyl-L-methionine_cycle_I           0.000158  0.000113
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...  0.000182  0.000154
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...  0.000180  0.000139
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...  0.000188  0.000165
# ...                                                      ...       ...
# PWY-5655:_L-tryptophan_degradation_IX               0.000000  0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)   0.000000  0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis            0.000000  0.000000
# PWY-7626:_bacilysin_biosynthesis                    0.000000  0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)      0.000000  0.000000
#
#                                                      train_4   train_5  \
# sample-id
# PWY-5686:_UMP_biosynthesis                          0.000147  0.000210
# PWY-6151:_S-adenosyl-L-methionine_cycle_I           0.000128  0.000175
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...  0.000155  0.000196
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...  0.000158  0.000191
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...  0.000144  0.000214
# ...                                                      ...       ...
# PWY-5655:_L-tryptophan_degradation_IX               0.000000  0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)   0.000000  0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis            0.000000  0.000000
# PWY-7626:_bacilysin_biosynthesis                    0.000000  0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)      0.000000  0.000000
#
#                                                      train_6   train_7  \
# sample-id
# PWY-5686:_UMP_biosynthesis                          0.000191  0.000164
# PWY-6151:_S-adenosyl-L-methionine_cycle_I           0.000139  0.000159
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...  0.000200  0.000157
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...  0.000197  0.000152
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...  0.000203  0.000151
# ...                                                      ...       ...
# PWY-5655:_L-tryptophan_degradation_IX               0.000000  0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)   0.000000  0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis            0.000000  0.000000
# PWY-7626:_bacilysin_biosynthesis                    0.000000  0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)      0.000000  0.000000
#
#                                                      train_8   train_9  ...  \
# sample-id                                                               ...
# PWY-5686:_UMP_biosynthesis                          0.000046  0.000559  ...
# PWY-6151:_S-adenosyl-L-methionine_cycle_I           0.000051  0.000457  ...
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...  0.000052  0.000581  ...
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...  0.000048  0.000591  ...
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...  0.000049  0.000489  ...
# ...                                                      ...       ...  ...
# PWY-5655:_L-tryptophan_degradation_IX               0.000000  0.000000  ...
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)   0.000000  0.000000  ...
# PWY-5109:_2-methylbutanoate_biosynthesis            0.000000  0.000000  ...
# PWY-7626:_bacilysin_biosynthesis                    0.000000  0.000000  ...
# PWY-7397:_naringenin_biosynthesis_(engineered)      0.000000  0.000000  ...
#
#                                                     train_4388  train_4389  \
# sample-id
# PWY-5686:_UMP_biosynthesis                            0.000438    0.000417
# PWY-6151:_S-adenosyl-L-methionine_cycle_I             0.000375    0.000373
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...    0.000425    0.000506
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...    0.000436    0.000551
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...    0.000469    0.000421
# ...                                                        ...         ...
# PWY-5655:_L-tryptophan_degradation_IX                 0.000000    0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)     0.000000    0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis              0.000000    0.000000
# PWY-7626:_bacilysin_biosynthesis                      0.000000    0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)        0.000000    0.000000
#
#                                                     train_4390  train_4391  \
# sample-id
# PWY-5686:_UMP_biosynthesis                            0.000700    0.000462
# PWY-6151:_S-adenosyl-L-methionine_cycle_I             0.000687    0.000455
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...    0.000667    0.000454
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...    0.000709    0.000427
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...    0.000667    0.000466
# ...                                                        ...         ...
# PWY-5655:_L-tryptophan_degradation_IX                 0.000000    0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)     0.000000    0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis              0.000000    0.000000
# PWY-7626:_bacilysin_biosynthesis                      0.000000    0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)        0.000000    0.000000
#
#                                                     train_4392  train_4393  \
# sample-id
# PWY-5686:_UMP_biosynthesis                            0.000599    0.000790
# PWY-6151:_S-adenosyl-L-methionine_cycle_I             0.000644    0.000764
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...    0.000597    0.000772
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...    0.000593    0.000746
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...    0.000558    0.000808
# ...                                                        ...         ...
# PWY-5655:_L-tryptophan_degradation_IX                 0.000000    0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)     0.000000    0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis              0.000000    0.000000
# PWY-7626:_bacilysin_biosynthesis                      0.000000    0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)        0.000000    0.000000
#
#                                                     train_4394  train_4395  \
# sample-id
# PWY-5686:_UMP_biosynthesis                            0.000571    0.000503
# PWY-6151:_S-adenosyl-L-methionine_cycle_I             0.000357    0.000450
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...    0.000543    0.000515
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...    0.000505    0.000469
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...    0.000500    0.000480
# ...                                                        ...         ...
# PWY-5655:_L-tryptophan_degradation_IX                 0.000000    0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)     0.000000    0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis              0.000000    0.000000
# PWY-7626:_bacilysin_biosynthesis                      0.000000    0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)        0.000000    0.000000
#
#                                                     train_4396  train_4397
# sample-id
# PWY-5686:_UMP_biosynthesis                            0.000463    0.000514
# PWY-6151:_S-adenosyl-L-methionine_cycle_I             0.000290    0.000407
# PWY-7221:_guanosine_ribonucleotides_de_novo_bio...    0.000494    0.000474
# PWY-7219:_adenosine_ribonucleotides_de_novo_bio...    0.000429    0.000421
# ILEUSYN-PWY:_L-isoleucine_biosynthesis_I_(from_...    0.000459    0.000521
# ...                                                        ...         ...
# PWY-5655:_L-tryptophan_degradation_IX                 0.000000    0.000000
# PWY-7255:_ergothioneine_biosynthesis_I_(bacteria)     0.000000    0.000000
# PWY-5109:_2-methylbutanoate_biosynthesis              0.000000    0.000000
# PWY-7626:_bacilysin_biosynthesis                      0.000000    0.000000
# PWY-7397:_naringenin_biosynthesis_(engineered)        0.000000    0.000000
#
# [619 rows x 1773 columns]

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

evaluations = []
gmhi = []
# Loop over each fold
for fold, (train_index, test_index) in enumerate(skf.split(data.T, labels)):
    # model_name = f'camda_pathways_fold{fold+1}'
    X_train, X_test = data.T.iloc[train_index], data.T.iloc[test_index]
    y_train, y_test = meta.iloc[train_index], meta.iloc[test_index]

    print(f"Fold {fold + 1}")
    
    metrics=get_fH_fN_dH_dN(y_train,X_train.T)
    MH,MN=get_MH_MN(metrics,theta_f,theta_d)
    GMHI=get_all_GMHI(X_test.T,MH,MN)
    gmhi.append(GMHI)
    accuracy=get_accuracy2(GMHI,y_test)
    # healthy_sub = [x for x in X_train.index if x in healthy]
    # nonhealthy_sub = [x for x in X_train.index if x in non_healthy]
    print(f'F1_score: {accuracy}')
    evaluations.append(accuracy)
# Out:
# Fold 1
# F1_score: 0.07650273224043715
# Fold 2
# F1_score: 0.1386138613861386
# Fold 3
# F1_score: 0.13872832369942195
# Fold 4
# F1_score: 0.14207650273224043
# Fold 5
# F1_score: 0.12903225806451613

# %%
pd.concat(gmhi).to_csv('GMHI_2025_pathways_PC.csv')

# %%
sum(evaluations) / len(evaluations)
# Out:
# 0.5387895508769157

# %%
pathways.T
# Out:
# # Pathway   UNINTEGRATED|g__Absiella.s__Absiella_dolichum  \
# SRR5946989                                            0.0
# SRR5983265                                            0.0
# SRR5946777                                            0.0
# SRR5946822                                            0.0
# SRR5946857                                            0.0
# ...                                                   ...
# SRR5946648                                            0.0
# SRR5946925                                            0.0
# ERR209694                                             0.0
# SRR5946668                                            0.0
# ERR209312                                             0.0
#
# # Pathway   UNINTEGRATED|g__Acetobacter.s__Acetobacter_sp_CAG_267  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acetobacter.s__Acetobacter_sp_CAG_977  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acholeplasma.s__Acholeplasma_sp_CAG_878  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acidaminococcus.s__Acidaminococcus_intestini  \
# SRR5946989                                            0.00000
# SRR5983265                                            0.00000
# SRR5946777                                            0.00000
# SRR5946822                                            0.02683
# SRR5946857                                            0.00000
# ...                                                       ...
# SRR5946648                                            0.00000
# SRR5946925                                            0.00000
# ERR209694                                             0.00000
# SRR5946668                                            0.00000
# ERR209312                                             0.00000
#
# # Pathway   UNINTEGRATED|g__Acinetobacter.s__Acinetobacter_idrijaensis  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acinetobacter.s__Acinetobacter_lwoffii  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_HMSC035G02  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_HPA0247  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_ICM47  ...  \
# SRR5946989                                                0.0    ...
# SRR5983265                                                0.0    ...
# SRR5946777                                                0.0    ...
# SRR5946822                                                0.0    ...
# SRR5946857                                                0.0    ...
# ...                                                       ...    ...
# SRR5946648                                                0.0    ...
# SRR5946925                                                0.0    ...
# ERR209694                                                 0.0    ...
# SRR5946668                                                0.0    ...
# ERR209312                                                 0.0    ...
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_atypica  \
# SRR5946989                                           0.000000
# SRR5983265                                           0.000000
# SRR5946777                                           0.000000
# SRR5946822                                           0.000000
# SRR5946857                                           0.000000
# ...                                                       ...
# SRR5946648                                           0.000000
# SRR5946925                                           0.000000
# ERR209694                                            0.000000
# SRR5946668                                           0.000002
# ERR209312                                            0.000000
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_denticariosi  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_dispar  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_infantium  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_parvula  \
# SRR5946989                                           0.000000
# SRR5983265                                           0.000000
# SRR5946777                                           0.000000
# SRR5946822                                           0.000000
# SRR5946857                                           0.000000
# ...                                                       ...
# SRR5946648                                           0.000000
# SRR5946925                                           0.000000
# ERR209694                                            0.000000
# SRR5946668                                           0.000075
# ERR209312                                            0.000000
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_rogosae  \
# SRR5946989                                           0.000000
# SRR5983265                                           0.000000
# SRR5946777                                           0.000000
# SRR5946822                                           0.000000
# SRR5946857                                           0.000000
# ...                                                       ...
# SRR5946648                                           0.000000
# SRR5946925                                           0.000000
# ERR209694                                            0.000000
# SRR5946668                                           0.000002
# ERR209312                                            0.000000
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_seminalis  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_tobetsuensis  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Victivallales_unclassified.s__Victivallales_bacterium_CCUG_44730  \
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Victivallis.s__Victivallis_vadensis
# SRR5946989                                                0.0
# SRR5983265                                                0.0
# SRR5946777                                                0.0
# SRR5946822                                                0.0
# SRR5946857                                                0.0
# ...                                                       ...
# SRR5946648                                                0.0
# SRR5946925                                                0.0
# ERR209694                                                 0.0
# SRR5946668                                                0.0
# ERR209312                                                 0.0
#
# [613 rows x 25519 columns]

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=21)

evaluations = []
# Loop over each fold
for fold, (train_index, test_index) in enumerate(skf.split(pathways.T, labels)):
    # model_name = f'camda_pathways_fold{fold+1}'
    X_train_pathways, X_test_pathways = pathways.T.iloc[train_index], pathways.T.iloc[test_index]
    X_train_tax, X_test_tax = tax.T.iloc[train_index], tax.T.iloc[test_index]

    X_train_un = X_train_pathways[[x for x in X_train.columns if 'UNINTEGRATED' in x]]
    X_train_in = X_train_pathways[[x for x in X_train.columns if 'UNINTEGRATED' not in x]]

    X_test_un = X_test_pathways[[x for x in X_test_pathways.columns if 'UNINTEGRATED' in x]]
    X_test_in = X_test_pathways[[x for x in X_test_pathways.columns if 'UNINTEGRATED' not in x]]
    
    y_train, y_test = meta.iloc[train_index], meta.iloc[test_index]

    print(f"Fold {fold + 1}")

    # print(X_train_tax)
    
    metrics=get_fH_fN_dH_dN(y_train,X_train_un.T)
    MH_un,MN_un=get_MH_MN(metrics,theta_f,theta_d)
    GMHI_train_un=get_all_GMHI(X_train_un.T,MH_un,MN_un)
    GMHI_test_un=get_all_GMHI(X_test_un.T,MH_un,MN_un)
    
    metrics=get_fH_fN_dH_dN(y_train,X_train_in.T)
    MH_in,MN_in=get_MH_MN(metrics,theta_f,theta_d)
    GMHI_train_in=get_all_GMHI(X_train_in.T,MH_in,MN_in)
    GMHI_test_in=get_all_GMHI(X_test_in.T,MH_in,MN_in)
    
    metrics=get_fH_fN_dH_dN(y_train,X_train_tax.T)
    MH_tax,MN_tax=get_MH_MN(metrics,theta_f,theta_d)
    GMHI_train_tax=get_all_GMHI(X_train_tax.T,MH_tax,MN_tax)
    GMHI_test_tax=get_all_GMHI(X_test_tax.T,MH_tax,MN_tax)

    new_data_train = pd.DataFrame(zip(GMHI_train_un, GMHI_train_in, GMHI_train_tax), columns = ['GMHI_unintegrated', 'GMHI_integrated', 'GMHI_taxonomy'])
    new_data_train.index = X_train_tax.index

    new_data_test = pd.DataFrame(zip(GMHI_test_un, GMHI_test_in, GMHI_test_tax), columns = ['GMHI_unintegrated', 'GMHI_integrated', 'GMHI_taxonomy'])
    new_data_test.index = X_test_tax.index
    # print(new_data_test.head(3))

    clf = RandomForestClassifier(max_depth=5, min_samples_leaf = 3, random_state=0)
    # clf = DecisionTreeClassifier(max_depth=5, min_samples_leaf = 3, random_state=0)
    clf.fit(new_data_train, ['Unhealthy' if x != 'Healthy' else 'Healthy' for x in y_train['Diagnosis']])

    pred = clf.predict(new_data_test)

    print(balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in y_test['Diagnosis']], pred))


    

    # print(GMHI_un)
    
    # accuracy=get_accuracy(GMHI,y_test)
    # # healthy_sub = [x for x in X_train.index if x in healthy]
    # # nonhealthy_sub = [x for x in X_train.index if x in non_healthy]
    # print(f'Balanced Accuracy: {accuracy}')
    # evaluations.append(accuracy)
# Out:
# Fold 1
# 0.8043650793650794
# Fold 2
# 0.8353174603174602
# Fold 3
# 0.803968253968254
# Fold 4
# 0.7787634408602151
# Fold 5
# 0.7696236559139785

# %% [markdown]
# # Final Model RF-GMHI

# %%
unintegrated = pathways.T[[x for x in pathways.index if 'UNINTEGRATED' in x]]
integrated = pathways.T[[x for x in pathways.index if 'UNINTEGRATED' not in x]]

# %%
metrics=get_fH_fN_dH_dN(meta,unintegrated.T)
MH_un,MN_un=get_MH_MN(metrics,theta_f,theta_d)
# print(MH_un,MN_un)
pd.DataFrame(zip(MH_un,MN_un), columns = ['Healthy', 'Unhealthy']).to_csv('model_data/pathways_unintegrated.csv', index = False)
GMHI_train_un=get_all_GMHI(unintegrated.T,MH_un,MN_un)
# GMHI_test_un=get_all_GMHI(X_test_un.T,MH_un,MN_un)
    
metrics=get_fH_fN_dH_dN(meta,integrated.T)
MH_in,MN_in=get_MH_MN(metrics,theta_f,theta_d)
pd.DataFrame(zip(MH_in,MN_in), columns = ['Healthy', 'Unhealthy']).to_csv('model_data/pathways_integrated.csv', index = False)
GMHI_train_in=get_all_GMHI(integrated.T,MH_in,MN_in)
# GMHI_test_in=get_all_GMHI(X_test_in.T,MH_in,MN_in)
    
metrics=get_fH_fN_dH_dN(meta,tax)
MH_tax,MN_tax=get_MH_MN(metrics,theta_f,theta_d)
pd.DataFrame(zip(MH_tax,MN_tax), columns = ['Healthy', 'Unhealthy']).to_csv('model_data/taxonomy.csv', index = False)
GMHI_train_tax=get_all_GMHI(tax,MH_tax,MN_tax)
# GMHI_test_tax=get_all_GMHI(X_test_tax.T,MH_tax,MN_tax)

new_data_train = pd.DataFrame(zip(GMHI_train_un, GMHI_train_in, GMHI_train_tax), columns = ['GMHI_unintegrated', 'GMHI_integrated', 'GMHI_taxonomy'])

new_data_train.index = tax.columns
print(new_data_train.head(3))

clf = RandomForestClassifier(max_depth=5, min_samples_leaf = 3, random_state=0)
clf.fit(new_data_train, ['Unhealthy' if x != 'Healthy' else 'Healthy' for x in meta['Diagnosis']])
with open('model_data/rf_gmhi.pkl', 'wb') as f:
    pickle.dump(clf, f)
# Out:
#             GMHI_unintegrated  GMHI_integrated  GMHI_taxonomy
# SRR5946989           2.956522         0.376066       3.216072
# SRR5983265           2.546234         4.130309       2.537224
# SRR5946777           3.154197         0.550126       3.225344

# %% [markdown]
# ## COVID data

# %%
meta_covid=pd.read_csv('../../DataSets/COVID/CAMDA_metadata.txt', sep="\t",index_col=0)
tax_covid=pd.read_csv('../../DataSets/COVID/CAMDA_taxa.txt', sep='\t',index_col=0)
pathways_covid=pd.read_csv('../../DataSets/COVID/CAMDA_pathways.txt', sep='\t',index_col=0)

# %%
unintegrated_covid = pathways_covid.T[[x for x in pathways_covid.index if 'UNINTEGRATED' in x]]
integrated_covid = pathways_covid.T[[x for x in pathways_covid.index if 'UNINTEGRATED' not in x]]

# %%
GMHI_covid_un=get_all_GMHI(unintegrated_covid.T,MH_un,MN_un)
GMHI_covid_in=get_all_GMHI(integrated_covid.T,MH_in,MN_in)
GMHI_covid_tax=get_all_GMHI(tax_covid,MH_tax,MN_tax)

# %%
covid_gmhi = pd.DataFrame(zip(GMHI_covid_un, GMHI_covid_in, GMHI_covid_tax), columns = ['GMHI_unintegrated', 'GMHI_integrated', 'GMHI_taxonomy'])

# %%
covid_gmhi.index = tax_covid.columns

# %%
covid_gmhi.head()
# Out:
#           GMHI_unintegrated  GMHI_integrated  GMHI_taxonomy
# Sample1a           2.000261              0.0       0.389201
# Sample1b           2.243550              0.0       1.368506
# Sample5a          -0.559261              0.0       0.837585
# Sample5b          -0.516629              0.0       0.741994
# Sample6a           1.405457              0.0       2.651577

# %%
clf.predict(covid_gmhi)
# Out:
# array(['Unhealthy', 'Healthy', 'Unhealthy', 'Unhealthy', 'Healthy',
#        'Unhealthy', 'Healthy', 'Healthy', 'Unhealthy', 'Unhealthy',
#        'Unhealthy', 'Unhealthy', 'Unhealthy', 'Unhealthy', 'Healthy',
#        'Healthy', 'Healthy', 'Healthy', 'Unhealthy', 'Unhealthy',
#        'Unhealthy', 'Unhealthy', 'Unhealthy', 'Unhealthy', 'Unhealthy',
#        'Unhealthy', 'Healthy', 'Healthy', 'Healthy', 'Healthy',
#        'Unhealthy', 'Unhealthy', 'Healthy', 'Healthy', 'Healthy',
#        'Healthy', 'Healthy', 'Unhealthy', 'Healthy', 'Healthy',
#        'Unhealthy', 'Unhealthy', 'Healthy', 'Healthy', 'Healthy',
#        'Healthy', 'Healthy', 'Healthy', 'Healthy', 'Unhealthy', 'Healthy',
#        'Healthy', 'Healthy', 'Healthy', 'Healthy', 'Healthy', 'Healthy',
#        'Healthy', 'Unhealthy', 'Unhealthy', 'Unhealthy', 'Unhealthy',
#        'Healthy', 'Healthy', 'Healthy', 'Healthy', 'Healthy', 'Healthy',
#        'Healthy', 'Unhealthy'], dtype='<U9')
