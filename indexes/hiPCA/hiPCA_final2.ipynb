# %% [markdown]
# # KS - hiPCA

# %% [markdown]
# In this notebook we replicate the Kolgomorov-Smirnov hiPCA index as described in (Zhu et al, 2023). We also capture all the experiments made in pursue to obtain the best result for the CAMDA 2024 challenge

# %% [markdown]
# First we import the necessary libraries to run this notebook

# %%
import pandas as pd
import numpy as np
from scipy.stats import kstest
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.stats import chi2, norm
from sklearn.metrics import balanced_accuracy_score

# %% [markdown]
# Now we need to read the data

# %%
taxonomy = pd.read_csv('../../DataSets/CAMDA/taxonomy.txt', sep = '\t', index_col = 0)
metadata = pd.read_csv('../../DataSets/CAMDA/metadata.csv')

# %% [markdown]
# We select the samples which have most of the species identified

# %%
good_samples = []
for c in taxonomy.columns:
    if sum(taxonomy[c]) > 90:
        good_samples.append(c)
taxonomy_aux = taxonomy[good_samples]

# %% [markdown]
# From previous experiments we obtained better performance taking out the samples labeled as Obese, that is the reason we are not going to consider them either

# %%
obese = list(metadata[metadata['Diagnosis'] == 'Obese']['SampleID'])
healthy = list(metadata[metadata['Diagnosis'] == 'Healthy']['SampleID'])
non_healthy = list(metadata[metadata['Diagnosis'] != 'Healthy']['SampleID'])
non_healthy = [x for x in non_healthy if x not in obese]

# %% [markdown]
# Next we will define a function to perform Kolmogorov-Smirnov test to find the most important features for the PCA model

# %%
def ks_test(df, healthy, non_healthy, method_ks = 'auto', p_val = 0.001):
    healthy_df = df[[x for x in df.columns if x in healthy]].T
    nonhealthy_df = df[[x for x in df.columns if x in non_healthy]].T
    healthy_features = []
    nonhealthy_features = []
    for feature in list(df.index):
        if kstest(list(healthy_df[feature]), list(nonhealthy_df[feature]), alternative = 'less', method = method_ks).pvalue <= p_val:
            healthy_features.append(feature)
        if kstest(list(nonhealthy_df[feature]), list(healthy_df[feature]), alternative = 'less', method = method_ks).pvalue <= p_val:
            nonhealthy_features.append(feature)
    print(f'# Healthy features selected by KS: {len(healthy_features)}')
    print(f'# Unheatlhy features selected by KS: {len(nonhealthy_features)}')
    return healthy_features, nonhealthy_features

# %% [markdown]
# Now we define the data preprocessing workflow as defined in the paper

# %%
def custom_transform(x):
    if x <= 1:
        return np.log2(2 * x + 0.00001)
    else:
        return np.sqrt(x)

# %%
def transform_data(df, healthy_features, nonhealthy_features):
    scaler = StandardScaler()
    # selected = df.T[[x for x in list(set(healthy_features + nonhealthy_features)) if x in df.T.columns]]
    aux = pd.DataFrame()
    for item in list(set(healthy_features + nonhealthy_features)):
        if item in df.index:
            aux[item] = list(df.T[item])
        else:
            aux[item] = [0 for x in range(len(df.T))]
    selected = aux.applymap(custom_transform)

    for c in selected.columns:
        scaler.fit(np.array(selected[c]).reshape(-1, 1))
        selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
        
    selected.index = df.T.index

    return selected

# %% [markdown]
# Then we define a function to perform PCA over the selected features only

# %%
def get_pca_data(df):
    pca = PCA()

    pca.fit(df)

    eigenvalues = pca.explained_variance_
    eigenvectors = pca.components_
    singular = pca.singular_values_
    
    pca_data = pd.DataFrame(zip(eigenvectors, eigenvalues, singular), columns = ('Eigenvectors', 'Explained_variance', 'Singular_values')).sort_values('Explained_variance', ascending = False)
    pca_data['%variance'] = pca_data['Explained_variance'] / sum(pca_data['Explained_variance'])
    pca_data = pca_data.sort_values('%variance', ascending = False)
    pca_data['%variance_cumulative'] = pca_data['%variance'].cumsum()
    
    return pca_data, pca

# %%
def calculate_pca_stats(df, variance_for_pc = 0.9, alpha = 0.05):
    pca = PCA()

    pca.fit(df)

    eigenvalues = pca.explained_variance_
    eigenvectors = pca.components_
    singular = pca.singular_values_
    
    pca_data = pd.DataFrame(zip(eigenvectors, eigenvalues, singular), columns = ('Eigenvectors', 'Explained_variance', 'Singular_values')).sort_values('Explained_variance', ascending = False)
    pca_data['%variance'] = pca_data['Explained_variance'] / sum(pca_data['Explained_variance'])
    pca_data = pca_data.sort_values('%variance', ascending = False)
    pca_data['%variance_cumulative'] = pca_data['%variance'].cumsum()
    
    principal_components = list(pca_data[pca_data['%variance_cumulative'] < variance_for_pc]['Eigenvectors'])
    print(f'# Principal Components selected: {len(principal_components)}')
    
    principal_values = list(pca_data[pca_data['%variance_cumulative'] < variance_for_pc]['Explained_variance'])
    D = np.array(principal_components).T @ np.linalg.inv(np.diag(principal_values)) @ np.array(principal_components)
    deg_free = len(principal_components) 
    # alpha = 0.05
    t2_threshold = chi2.ppf(1-alpha, deg_free)
    print(1-alpha, deg_free)
    print(t2_threshold)
    
    principal_components_residual = list(pca_data[pca_data['%variance_cumulative'] >= variance_for_pc]['Eigenvectors'])
    principal_values_residual = list(pca_data[pca_data['%variance_cumulative'] >= variance_for_pc]['Explained_variance'])
    principal_singvalues_residual = list(pca_data[pca_data['%variance_cumulative'] >= variance_for_pc]['Singular_values'])
    
    C = np.array(principal_components_residual).T @ np.array(principal_components_residual)
    Theta1 = sum(principal_values_residual)
    Theta2 = sum([x**2 for x in principal_values_residual])
    Theta3 = sum([x**3 for x in principal_values_residual])
    
    c_alpha = norm.ppf(1-alpha)
    
    h0 = 1-((2*Theta1*Theta3)/(3*Theta2**2))
    
    Q_alpha = Theta1*(((((c_alpha*np.sqrt(2*Theta2*(h0**2)))/Theta1)+1+((Theta2*h0*(h0-1))/(Theta1**2))))**(1/h0))
    
    fi = D/t2_threshold + (np.eye(len(principal_components[0])) - (np.array(principal_components).T @ np.array(principal_components)))/Q_alpha
    g = ((len(principal_components) / t2_threshold**2) + (Theta2 / Q_alpha**2)) / ((len(principal_components)/t2_threshold) + (Theta1 / Q_alpha))
    h = ((len(principal_components)/t2_threshold) + (Theta1 / Q_alpha))**2 / ((len(principal_components) / t2_threshold**2) + (Theta2 / Q_alpha**2))

    chi_value = chi2.ppf(1-alpha, h)
    threshold_combined = g*chi_value
    
    return pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined

# %%
def calculate_stats(pca, samples_df):
    for item in pca.transform(samples_df):
        index = item.T @ D @ item
        T2.append(index)
        if index > t2_threshold:
            pred.append('Unhealthy')
        else:
            pred.append('Healthy')

# %% [markdown]
# After that we start calculating the indexes, below there is a function to calculate T^2 index

# %%
def hotelling_t2(df, pca, pca_data, variance_for_pc = 0.9, alpha = 0.05):
    principal_components = list(pca_data[pca_data['%variance_cumulative'] < variance_for_pc]['Eigenvectors'])
    print(f'# Principal Components selected: {len(principal_components)}')
    principal_values = list(pca_data[pca_data['%variance_cumulative'] < variance_for_pc]['Explained_variance'])
    D = np.array(principal_components).T @ np.linalg.inv(np.diag(principal_values)) @ np.array(principal_components)
    deg_free = len(principal_components) 
    # alpha = 0.05
    t2_threshold = chi2.ppf(1-alpha, deg_free)
    T2 = []
    pred = []
    
    try:
        for item in pca.transform(df):
            index = item.T @ D @ item
            T2.append(index)
            if index > t2_threshold:
                pred.append('Unhealthy')
            else:
                pred.append('Healthy')
    except:
        for item in np.array(df):
            index = item.T @ D @ item
            T2.append(index)
            if index > t2_threshold:
                pred.append('Unhealthy')
            else:
                pred.append('Healthy')
            
    hoteling = pd.DataFrame(zip(df.index, T2, pred), columns = ['Sample', 'T2', 'Prediction T2'])
    
    return D, principal_components, hoteling, t2_threshold

# %% [markdown]
# Here we made a modification to Q_statistic limit according to ()

# %%
def Q_statistic(df, pca, pca_data, variance_for_pc = 0.9, alpha = 0.05):
    principal_components_residual = list(pca_data[pca_data['%variance_cumulative'] >= variance_for_pc]['Eigenvectors'])
    principal_values_residual = list(pca_data[pca_data['%variance_cumulative'] >= variance_for_pc]['Explained_variance'])
    principal_singvalues_residual = list(pca_data[pca_data['%variance_cumulative'] >= variance_for_pc]['Singular_values'])
    
    C = np.array(principal_components_residual).T @ np.array(principal_components_residual)
    Theta1 = sum(principal_values_residual)
    Theta2 = sum([x**2 for x in principal_values_residual])
    Theta3 = sum([x**3 for x in principal_values_residual])
    
    c_alpha = norm.ppf(1-alpha)
    
    h0 = 1-((2*Theta1*Theta3)/(3*Theta2**2))
    
    Q_alpha = Theta1*(((((c_alpha*np.sqrt(2*Theta2*(h0**2)))/Theta1)+1+((Theta2*h0*(h0-1))/(Theta1**2))))**(1/h0))
    
    Q = []
    pred = []
    try:
        for item in pca.transform(df):
            index = item.T @ C @ item
            Q.append(index)
            if index > Q_alpha:
                pred.append('Unhealthy')
            else:
                pred.append('Healthy')
    except:
        for item in np.array(df):
            index = item.T @ C @ item
            Q.append(index)
            if index > Q_alpha:
                pred.append('Unhealthy')
            else:
                pred.append('Healthy')
    
    Q_statistic = pd.DataFrame(zip(df.index, Q, pred), columns = ['Sample', 'Q', 'Prediction Q'])
    
    return C, Theta1, Theta2, Q_statistic, Q_alpha

# %%
def combined_index(df, D, t2_threshold, principal_components, Q_alpha, Theta1, Theta2, pca, alpha = 0.05):
    fi = D/t2_threshold + (np.eye(len(principal_components[0])) - (np.array(principal_components).T @ np.array(principal_components)))/Q_alpha
    g = ((len(principal_components) / t2_threshold**2) + (Theta2 / Q_alpha**2)) / ((len(principal_components)/t2_threshold) + (Theta1 / Q_alpha))
    h = ((len(principal_components)/t2_threshold) + (Theta1 / Q_alpha))**2 / ((len(principal_components) / t2_threshold**2) + (Theta2 / Q_alpha**2))

    chi_value = chi2.ppf(1-alpha, h)
    threshold_combined = g*chi_value
    combined = []
    pred = []
    print(threshold_combined)
    try:
        for item in pca.transform(df):
            index = item.T @ fi @ item
            combined.append(index)
            if index > threshold_combined:
                pred.append('Unhealthy')
            else:
                pred.append('Healthy')
    except:
        for item in np.array(df):
            index = item.T @ fi @ item
            combined.append(index)
            if index > threshold_combined:
                pred.append('Unhealthy')
            else:
                pred.append('Healthy')

    combined = pd.DataFrame(zip(df.index, combined, pred), columns = ['Sample', 'Combined', 'Prediction Combined']) 
    return combined

# %% [markdown]
# Finally we define a function to calculate the index

# %%
def hiPCA(df, healthy, non_health, df_ks = [], healthy_features = [], non_healthy_features = [], ks = False, method = 'auto', p_val = 0.001, only_nonhealthy_features = False):
    if ks:
        healthy_features, non_healthy_features = ks_test(df_ks, healthy, non_healthy, method_ks = method, p_val = p_val)
        
    if only_nonhealthy_features:
        selected = transform_data(df, [], non_healthy_features)
    else:
        selected = transform_data(df, healthy_features, non_healthy_features)
    
    # print(selected)
    pca_data, pca = get_pca_data(selected.T[healthy].T)
    D, principal_components, results_hotelling, t2_threshold = hotelling_t2(selected, pca, pca_data)
    C, Theta1, Theta2, results_q, Q_alpha = Q_statistic(selected, pca, pca_data)
    hiPCA = combined_index(selected, D, t2_threshold, principal_components, Q_alpha, Theta1, Theta2, pca)
    
    return healthy_features, non_healthy_features, pd.concat([results_hotelling, results_q.drop('Sample', axis = 1),  hiPCA.drop('Sample', axis = 1)], axis=1, join='outer')

# %%
def hiPCA2(df, healthy, non_healthy, healthy_features = [], non_healthy_features = [], ks = False, method = 'auto', p_val = 0.001, only_nonhealthy_features = False):
    if ks:
        healthy_features, non_healthy_features = ks_test(df, healthy, non_healthy, method_ks = method, p_val = p_val)
        
    if only_nonhealthy_features:
        selected = transform_data(df, [], non_healthy_features)
    else:
        selected = transform_data(df, healthy_features, non_healthy_features)
        
    pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined = calculate_pca_stats(selected)
    print(t2_threshold, Q_alpha, threshold_combined)

# %%
def hiPCA3(df, healthy, non_healthy, df_ks = [], healthy_features = [], non_healthy_features = [], ks = False, method = 'auto', p_val = 0.001, only_nonhealthy_features = False):
    if ks:
        healthy_features, non_healthy_features = ks_test(df_ks, healthy, non_healthy, method_ks = method, p_val = p_val)
        
    if only_nonhealthy_features:
        selected = transform_data(df[[x for x in healthy if x in df.columns]], [], non_healthy_features)
    else:
        selected = transform_data(df[[x for x in healthy if x in df.columns]], healthy_features, non_healthy_features)
    
    # print(selected)
    pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined = calculate_pca_stats(selected)
    print(t2_threshold, Q_alpha, threshold_combined)
        
    return healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Experiment 1

# %% [markdown]
# First we will calculate KS-hiPCA index to the trainning data and evaluate its result using balanced accuracy

# %%
metadata
# Out:
#     Diagnosis      Project    SampleID      GMHI      hiPCA  Shannon_entropy
# 0     Healthy         HMP2  SRR5946989  1.977597   0.805751         3.585040
# 1     Healthy  PRJNA389280  SRR5983265  1.036363   9.604431         4.516999
# 2     Healthy         HMP2  SRR5946777  2.079383   0.605478         5.132696
# 3          CD         HMP2  SRR5946822 -2.522606   3.317453         2.971195
# 4     Healthy         HMP2  SRR5946857  0.260267   2.921465         4.491431
# ..        ...          ...         ...       ...        ...              ...
# 608        CD         HMP2  SRR5946648 -0.257764   3.582903         2.348565
# 609   Healthy         HMP2  SRR5946925  0.663667   2.553392         4.186847
# 610   Healthy    PRJEB1220   ERR209694 -0.262792  14.573817         5.606539
# 611        CD         HMP2  SRR5946668 -3.183020  10.761874         3.802272
# 612     Obese    PRJEB1220   ERR209312  0.000000   0.246087         5.741620
#
# [613 rows x 6 columns]

# %%
obese = list(metadata[metadata['Diagnosis'] == 'Obese']['SampleID'])
healthy = list(metadata[metadata['Diagnosis'] == 'Healthy']['SampleID'])
non_healthy = list(metadata[metadata['Diagnosis'] != 'Healthy']['SampleID'])
non_healthy = [x for x in non_healthy if x not in obese]

# %%
taxonomy_not_obese = taxonomy_aux[[x for x in taxonomy_aux if x not in obese]]

# %%
taxonomy_transposed = taxonomy_not_obese.T

# %%
# taxonomy_transposed['Label'] = ['Healthy' if x == 'Healthy' else 'Unhealthy' for x in list(metadata['Diagnosis'])]

# %%
label = []
for item in taxonomy_transposed.T.columns:
    if metadata[metadata['SampleID'] == item]['Diagnosis'].iloc[0] == 'Healthy':
        label.append('Healthy')
    else:
        label.append('Unhealthy')

# %%
# taxonomy_transposed = taxonomy_transposed.T[taxonomy_aux.columns].T

# %%
# taxonomy_transposed

# %% [markdown]
# ### TESTING

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(taxonomy_transposed, label, test_size=0.20, random_state=20, stratify = label)

# %%
healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(X_train.T, healthy, non_healthy, df_ks = X_train.T, ks = True, method = 'asymp', only_nonhealthy_features = True)
# Out:
# # Healthy features selected by KS: 130
# # Unheatlhy features selected by KS: 17
# # Principal Components selected: 10
# 0.95 10
# 18.307038053275146
# 18.307038053275146 4.198301915746638 1.6919901191461653

# %%
test_transformed = transform_data(X_test.T, [], non_healthy_features)

# %%
healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(X_train.T, healthy, non_healthy, df_ks = X_train.T, ks = True, method = 'asymp', only_nonhealthy_features = False)
# Out:
# # Healthy features selected by KS: 130
# # Unheatlhy features selected by KS: 17
# # Principal Components selected: 51
# 0.95 51
# 68.66929391228578
# 68.66929391228578 20.365473937778415 1.8419064612150682

# %%
test_transformed = transform_data(X_test.T, healthy_features, non_healthy_features)

# %%
len(X_train)
# Out:
# 401

# %%
train_transformed = transform_data(X_train.T, [], non_healthy_features)

# %%
len(train_transformed)
# Out:
# 401

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in pca.transform(train_transformed):
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results_train = pd.DataFrame(zip(train_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
results_train
# Out:
#        SampleID         T2 Prediction T2          Q Prediction Q  \
# 0     ERR209799   1.402994       Healthy   4.784865    Unhealthy
# 1    SRR5983354   6.423970       Healthy   2.792262      Healthy
# 2    SRR5946648   2.422791       Healthy   3.900467      Healthy
# 3     ERR209854  13.887102       Healthy   2.638236      Healthy
# 4    SRR5935795   2.162224       Healthy   5.528409    Unhealthy
# ..          ...        ...           ...        ...          ...
# 396  SRR5935770   2.138255       Healthy   1.997195      Healthy
# 397  SRR5935891  12.994175       Healthy  10.881675    Unhealthy
# 398  SRR5946762   5.745383       Healthy   4.191088    Unhealthy
# 399  SRR5947012   5.374624       Healthy   4.183521    Unhealthy
# 400  SRR5935823  13.990091       Healthy   7.910716    Unhealthy
#
#      Combined Index Combined Prediction
# 0          1.231402             Healthy
# 1          1.024778             Healthy
# 2          1.073669             Healthy
# 3          1.395270             Healthy
# 4          1.452319             Healthy
# ..              ...                 ...
# 396        0.598797             Healthy
# 397        3.335942           Unhealthy
# 398        1.325299             Healthy
# 399        1.303221             Healthy
# 400        2.673340           Unhealthy
#
# [401 rows x 7 columns]

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in pca.transform(test_transformed):
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results = pd.DataFrame(zip(test_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
# results['TRUE'] = list(y_test)

# %%
balanced_accuracy_score(results['Combined Prediction'], list(y_test))
# Out:
# C:\Users\rafap\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1999: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 0.48514851485148514

# %%
balanced_accuracy_score(results['Prediction T2'], list(y_test))
# Out:
# 0.35

# %%
balanced_accuracy_score(results['Prediction Q'], list(y_test))
# Out:
# C:\Users\rafap\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1999: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# 0.48514851485148514

# %%
healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(X_train.T, healthy, non_healthy, df_ks = X_train.T, ks = False, method = 'auto', only_nonhealthy_features = True, non_healthy_features=list(unhealthy_tax['species']))
# Out:
# # Principal Components selected: 23
# 0.95 23
# 35.17246162690806
# 35.17246162690806 7.507711665443201 1.7623337048363399

# %%
test_transformed = transform_data(X_test.T, [], list(unhealthy_tax['species']))

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in pca.transform(test_transformed):
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results = pd.DataFrame(zip(test_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
balanced_accuracy_score(results['Combined Prediction'], list(y_test))
# Out:
# 0.6414634146341464

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/ANCOM-BC_pvalue 0.005.txt', sep="\t")

# %%
healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(X_train.T, healthy, non_healthy, df_ks = X_train.T, ks = False, method = 'asymp', only_nonhealthy_features = True, non_healthy_features=list(unhealthy_tax['Species']))
# Out:
# # Principal Components selected: 21
# 0.95 21
# 32.670573340917315
# 32.670573340917315 6.708659174942156 1.755545616723695

# %%
test_transformed = transform_data(X_test.T, [], list(unhealthy_tax['Species']))

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in pca.transform(test_transformed):
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results = pd.DataFrame(zip(test_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
balanced_accuracy_score(results['Combined Prediction'], list(y_test))
# Out:
# 0.4613526570048309

# %%
balanced_accuracy_score(results['Prediction T2'], list(y_test))
# Out:
# 0.5747377622377623

# %%
balanced_accuracy_score(results['Prediction Q'], list(y_test))
# Out:
# 0.36211340206185566

# %%
results['true'] = y_test

# %%
results[results['Combined Prediction'] == 'Healthy']
# Out:
#       SampleID         T2 Prediction T2         Q Prediction Q  \
# 82  SRR5946874  17.392177       Healthy  9.280078    Unhealthy
#
#     Combined Index Combined Prediction     true
# 82        1.644097             Healthy  Healthy

# %%
un2 = ['Bacteroides_fragilis',
 'Clostridium_symbiosum',
 'Enterocloster_aldenensis',
 'Enterocloster_bolteae',
 'Enterocloster_clostridioformis',
 'Erysipelatoclostridium_ramosum',
 'Escherichia_coli',
 'Flavonifractor_plautii',
 'Hungatella_hathewayi',
 'Ruminococcus_gnavus',
 'Veillonella_parvula']

# %%
healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(X_train.T, healthy, non_healthy, df_ks = X_train.T, ks = False, method = 'auto', only_nonhealthy_features = True, non_healthy_features=un2)
# Out:
# # Principal Components selected: 7
# 0.95 7
# 14.067140449340167
# 14.067140449340167 2.8656083142109576 1.655722273093897

# %%
test_transformed = transform_data(X_test.T, [], un2)

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in pca.transform(test_transformed):
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results = pd.DataFrame(zip(test_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
balanced_accuracy_score(results['Combined Prediction'], list(y_test))
# Out:
# 0.7255412991178829

# %%
results['TRUE'] = list(y_test)

# %%
results.head(50)
# Out:
#       SampleID         T2 Prediction T2          Q Prediction Q  \
# 0   SRR5935802  23.286220     Unhealthy  15.956880    Unhealthy
# 1   SRR5947102  21.507794     Unhealthy   5.914778    Unhealthy
# 2   SRR5946673  36.299243     Unhealthy  18.928025    Unhealthy
# 3    ERR209749  42.888788     Unhealthy   9.599707    Unhealthy
# 4   SRR5935984   9.419097       Healthy   3.352874      Healthy
# 5   SRR5946630  12.743590       Healthy   8.628717    Unhealthy
# 6    ERR210591  12.957113       Healthy   6.588999    Unhealthy
# 7    ERR209748  42.515783     Unhealthy   9.381326    Unhealthy
# 8    ERR209746  13.201642       Healthy   3.950944      Healthy
# 9   SRR5946772   9.782545       Healthy   8.328916    Unhealthy
# 10  SRR5947017   3.017817       Healthy   3.184110      Healthy
# 11   ERR210092   6.091298       Healthy   4.443272    Unhealthy
# 12  SRR5936223  13.728628       Healthy   6.872340    Unhealthy
# 13  SRR5935968   5.185558       Healthy   4.227577    Unhealthy
# 14  SRR5936041   2.216944       Healthy   3.039493      Healthy
# 15  SRR5947832  10.163258       Healthy   6.903289    Unhealthy
# 16  SRR5946834   1.486527       Healthy   5.158500    Unhealthy
# 17  SRR5946952   7.441224       Healthy   3.234727      Healthy
# 18  SRR5983277   4.168715       Healthy   4.473961    Unhealthy
# 19   ERR209162   6.091298       Healthy   4.443272    Unhealthy
# 20  SRR5983459   8.822527       Healthy  26.954808    Unhealthy
# 21   ERR209740   7.493911       Healthy   7.508711    Unhealthy
# 22   ERR210283   8.102482       Healthy   3.593580      Healthy
# 23  SRR5947838   2.509334       Healthy   7.578207    Unhealthy
# 24   ERR210523   6.091298       Healthy   4.443272    Unhealthy
# 25  SRR5983376   5.061168       Healthy   5.413276    Unhealthy
# 26  SRR5947081   2.672779       Healthy   3.412536      Healthy
# 27  SRR5983422   4.770123       Healthy   2.719630      Healthy
# 28  SRR5983333   1.504612       Healthy   5.007772    Unhealthy
# 29  SRR5946762  11.377277       Healthy   3.647656      Healthy
# 30  SRR5936132   2.791485       Healthy   4.273172    Unhealthy
# 31   ERR210592   7.304650       Healthy   4.528274    Unhealthy
# 32  SRR5935975   5.836783       Healthy   2.337005      Healthy
# 33  SRR5946689   4.138279       Healthy   3.025938      Healthy
# 34  SRR5983355   7.897477       Healthy  10.329460    Unhealthy
# 35  SRR5946799  13.550149       Healthy   2.022373      Healthy
# 36  SRR5935827   7.136231       Healthy   2.539253      Healthy
# 37  SRR5935996  14.023951       Healthy   0.766853      Healthy
# 38  SRR5947104   4.239684       Healthy   5.105656    Unhealthy
# 39  SRR5946853   8.648108       Healthy  11.825752    Unhealthy
# 40  SRR5935743   6.091298       Healthy   4.443272    Unhealthy
# 41  SRR5935923  22.545862     Unhealthy  11.552091    Unhealthy
# 42  SRR5946846  18.668640     Unhealthy  11.858439    Unhealthy
# 43   ERR210578   6.091298       Healthy   4.443272    Unhealthy
# 44  SRR5936092  19.170455     Unhealthy   5.922308    Unhealthy
# 45   ERR209404   7.605319       Healthy   3.371434      Healthy
# 46  SRR5946924   1.898316       Healthy   4.135344      Healthy
# 47  SRR5946863   3.786362       Healthy   4.728840    Unhealthy
# 48  SRR5947843   9.154721       Healthy  11.894444    Unhealthy
# 49  SRR5947045   4.083860       Healthy   3.614626      Healthy
#
#     Combined Index Combined Prediction       TRUE
# 0         5.072776           Unhealthy  Unhealthy
# 1         2.583687           Unhealthy  Unhealthy
# 2         6.491298           Unhealthy  Unhealthy
# 3         4.629318           Unhealthy  Unhealthy
# 4         1.313133             Healthy    Healthy
# 5         2.751391           Unhealthy  Unhealthy
# 6         2.277211           Unhealthy  Unhealthy
# 7         4.556926           Unhealthy  Unhealthy
# 8         1.662205             Healthy  Unhealthy
# 9         2.518237           Unhealthy    Healthy
# 10        0.923273             Healthy    Healthy
# 11        1.391080             Healthy    Healthy
# 12        2.386843           Unhealthy  Unhealthy
# 13        1.290228             Healthy    Healthy
# 14        0.845079             Healthy    Healthy
# 15        2.199461           Unhealthy  Unhealthy
# 16        1.309911             Healthy    Healthy
# 17        1.176952             Healthy    Healthy
# 18        1.293371             Healthy  Unhealthy
# 19        1.391080             Healthy    Healthy
# 20        6.902327           Unhealthy  Unhealthy
# 21        2.197857           Unhealthy  Unhealthy
# 22        1.298549             Healthy    Healthy
# 23        1.942134           Unhealthy  Unhealthy
# 24        1.391080             Healthy    Healthy
# 25        1.565857             Healthy    Healthy
# 26        0.958835             Healthy    Healthy
# 27        0.908355             Healthy  Unhealthy
# 28        1.274997             Healthy  Unhealthy
# 29        1.490311             Healthy    Healthy
# 30        1.170315             Healthy    Healthy
# 31        1.477604             Healthy  Unhealthy
# 32        0.875482             Healthy    Healthy
# 33        0.946801             Healthy    Healthy
# 34        2.891780           Unhealthy  Unhealthy
# 35        1.221873             Healthy  Unhealthy
# 36        0.994637             Healthy    Healthy
# 37        0.948699             Healthy  Unhealthy
# 38        1.447712             Healthy    Healthy
# 39        3.289187           Unhealthy  Unhealthy
# 40        1.391080             Healthy  Unhealthy
# 41        3.983151           Unhealthy  Unhealthy
# 42        3.844332           Unhealthy    Healthy
# 43        1.391080             Healthy    Healthy
# 44        2.457807           Unhealthy  Unhealthy
# 45        1.218479             Healthy    Healthy
# 46        1.088697             Healthy    Healthy
# 47        1.333195             Healthy  Unhealthy
# 48        3.333222           Unhealthy  Unhealthy
# 49        1.084049             Healthy    Healthy

# %%
T2
# Out:
# [8.78694456157465,
#  5.724143766057815,
#  19.17719470489543,
#  7.159069222502472,
#  9.455144743808866,
#  10.977173511651811,
#  23.659226745766325,
#  50.826464009732824,
#  7.559861860432868,
#  6.292424681383243,
#  6.251766888621732,
#  17.774537953769013,
#  6.152618930107254,
#  4.4871676444167115,
#  21.716556714040834,
#  3.6410136179915265,
#  7.322730700390331,
#  13.480883139621954,
#  16.267657323631084,
#  3.8352507750569393,
#  4.829976058631994,
#  36.575773653392545,
#  4.041692690985719,
#  3.465308929046774,
#  9.206031693701282,
#  2.8535279354397574,
#  8.144443754481168,
#  14.868969942515605,
#  2.7010445979357267,
#  7.056319105495712,
#  2.4095489324344332,
#  3.75938044514283,
#  6.829728307567452,
#  4.245911274475965,
#  8.129956109366857,
#  7.67202668569921,
#  6.166378000784345,
#  6.615705598372675,
#  29.41203301575717,
#  45.50430271422011,
#  1.7722906494189137,
#  1.9140410030117698,
#  5.157944889477502,
#  12.40263254715239,
#  10.691575930171869,
#  7.4778121061123075,
#  7.644091028044516,
#  44.068213497172074,
#  8.48851667886725,
#  8.769661060858162,
#  21.889784861107533,
#  4.38594436222696,
#  14.809821464091629,
#  11.608858257743615,
#  16.7686455653153,
#  11.925792640830345,
#  9.653698162114239,
#  46.40315491140679,
#  4.062312507434508,
#  9.332630183718491,
#  15.12571352128867,
#  6.837723791762856,
#  8.785336260310284,
#  14.240530158768317,
#  3.732216942042724,
#  8.587673636381684,
#  3.0669397902925457,
#  7.107866001408427,
#  5.597903669840094,
#  15.244464624965795,
#  24.295375664111223,
#  6.90593247568163,
#  10.112000118109066,
#  6.152097853438244,
#  8.108140722920586,
#  10.486822481735189,
#  15.098531575028295,
#  4.115973976812183,
#  4.487037139225462,
#  2.9002836331933195,
#  5.809607198441629,
#  9.0806364122675,
#  5.761339833703514,
#  4.086555030929835,
#  3.6410136179915265,
#  5.612221069740066,
#  3.868965146745827,
#  11.435317007990294,
#  51.02677995873545,
#  5.486747228594508,
#  12.952556018172825,
#  3.162895854954758,
#  8.468697957610436,
#  3.3155097144903793,
#  6.279944700180048,
#  32.71840464961025,
#  6.2400176468771145,
#  9.072586786640152,
#  7.5730098222830415,
#  5.9748107267447175,
#  2.8560402247371344,
#  3.6410136179915265,
#  3.0964857063433646,
#  11.444567192167177,
#  7.299293065917194,
#  3.6410136179915265]

# %%
y_train
# Out:
# ERR209298     Unhealthy
# SRR5983470    Unhealthy
# SRR5935805    Unhealthy
# SRR5936014      Healthy
# SRR5947008    Unhealthy
#                 ...
# SRR5936186    Unhealthy
# SRR5946723      Healthy
# SRR5935915      Healthy
# ERR210536     Unhealthy
# ERR210220       Healthy
# Name: Label, Length: 422, dtype: object

# %%
pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(taxonomy, healthy, non_healthy, df_ks = taxonomy_aux, ks = True, method = 'asymp', only_nonhealthy_features = True)
# Out:
# # Healthy features selected by KS: 140
# # Unheatlhy features selected by KS: 22
# # Principal Components selected: 13
# 0.95 13
# 22.362032494826934
# 22.362032494826934 4.958097208913289 1.708343213455037

# %%
original_hiPCA = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']], ['Unhealthy' if x > 3.8 else 'Healthy' for x in metadata['hiPCA']])

# %%
ks_hiPCA = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])

# %%
t2_hiPCA = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])

# %%
q_hiPCA = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'KS - hiPCA (T^2) : {t2_hiPCA}')
print(f'KS - hiPCA (Q) : {q_hiPCA}')
print(f'KS - hiPCA (Combined): {ks_hiPCA}')
# Out:
# Given hiPCA: 0.6726198083067092
# KS - hiPCA (T^2) : 0.7310330138445155
# KS - hiPCA (Q) : 0.6390521831735889
# KS - hiPCA (Combined): 0.6837859424920127

# %% [markdown]
# >Note that we did not have the threshold for the given hiPCA to classify samples, we arbitrarly chose the threshold that gave best result to make a fair comparison

# %% [markdown]
# Now we will use this model to try to predict the unhealthy samples

# %%
taxonomy_covid = pd.read_csv('../../DataSets/COVID/CAMDA_taxa.txt', sep = '\t', index_col = 0)

# %%
taxonomy_covid.T
# Out:
# SampleID   Klebsiella_pneumoniae  Leuconostoc_lactis  Enterococcus_faecium  \
# Sample1a                     0.0                 0.0                0.0000
# Sample1b                     0.0                 0.0                4.1925
# Sample5a                     0.0                 0.0                0.0000
# Sample5b                     0.0                 0.0                0.0000
# Sample6a                     0.0                 0.0                0.0000
# ...                          ...                 ...                   ...
# Sample95b                    0.0                 0.0                0.0000
# Sample96b                    0.0                 0.0                0.0000
# Sample96a                    0.0                 0.0                0.0000
# Sample98a                    0.0                 0.0                0.0000
# Sample98b                    0.0                 0.0                0.0000
#
# SampleID   Veillonella_parvula  Escherichia_coli  Enterococcus_faecalis  \
# Sample1a                   0.0           0.00000                    0.0
# Sample1b                   0.0           0.00000                    0.0
# Sample5a                   0.0           2.43983                    0.0
# Sample5b                   0.0           3.21447                    0.0
# Sample6a                   0.0           0.00000                    0.0
# ...                        ...               ...                    ...
# Sample95b                  0.0           0.00000                    0.0
# Sample96b                  0.0           0.00000                    0.0
# Sample96a                  0.0           0.00000                    0.0
# Sample98a                  0.0           0.00000                    0.0
# Sample98b                  0.0           0.00000                    0.0
#
# SampleID   Bifidobacterium_animalis  Clostridium_SGB6177  \
# Sample1a                        0.0                  0.0
# Sample1b                        0.0                  0.0
# Sample5a                        0.0                  0.0
# Sample5b                        0.0                  0.0
# Sample6a                        0.0                  0.0
# ...                             ...                  ...
# Sample95b                       0.0                  0.0
# Sample96b                       0.0                  0.0
# Sample96a                       0.0                  0.0
# Sample98a                       0.0                  0.0
# Sample98b                       0.0                  0.0
#
# SampleID   Clostridioides_difficile  Enterococcus_raffinosus  ...  \
# Sample1a                        0.0                      0.0  ...
# Sample1b                        0.0                      0.0  ...
# Sample5a                        0.0                      0.0  ...
# Sample5b                        0.0                      0.0  ...
# Sample6a                        0.0                      0.0  ...
# ...                             ...                      ...  ...
# Sample95b                       0.0                      0.0  ...
# Sample96b                       0.0                      0.0  ...
# Sample96a                       0.0                      0.0  ...
# Sample98a                       0.0                      0.0  ...
# Sample98b                       0.0                      0.0  ...
#
# SampleID   GGB4591_SGB6350  Lactobacillus_acidophilus  GGB4605_SGB6376  \
# Sample1a               0.0                    0.00000              0.0
# Sample1b               0.0                    0.00000              0.0
# Sample5a               0.0                    0.00000              0.0
# Sample5b               0.0                    0.00000              0.0
# Sample6a               0.0                    0.00000              0.0
# ...                    ...                        ...              ...
# Sample95b              0.0                    0.00000              0.0
# Sample96b              0.0                    0.00000              0.0
# Sample96a              0.0                    0.00000              0.0
# Sample98a              0.0                    0.06305              0.0
# Sample98b              0.0                    0.00000              0.0
#
# SampleID   GGB27106_SGB6188  Methanomassiliicoccaceae_unclassified_SGB380  \
# Sample1a                0.0                                           0.0
# Sample1b                0.0                                           0.0
# Sample5a                0.0                                           0.0
# Sample5b                0.0                                           0.0
# Sample6a                0.0                                           0.0
# ...                     ...                                           ...
# Sample95b               0.0                                           0.0
# Sample96b               0.0                                           0.0
# Sample96a               0.0                                           0.0
# Sample98a               0.0                                           0.0
# Sample98b               0.0                                           0.0
#
# SampleID   GGB4641_SGB6420  Candidatus_Neoclostridium_roslinense  \
# Sample1a               0.0                                   0.0
# Sample1b               0.0                                   0.0
# Sample5a               0.0                                   0.0
# Sample5b               0.0                                   0.0
# Sample6a               0.0                                   0.0
# ...                    ...                                   ...
# Sample95b              0.0                                   0.0
# Sample96b              0.0                                   0.0
# Sample96a              0.0                                   0.0
# Sample98a              0.0                                   0.0
# Sample98b              0.0                                   0.0
#
# SampleID   GGB9608_SGB15041  GGB4661_SGB6449  GGB3169_SGB4183
# Sample1a                0.0              0.0              0.0
# Sample1b                0.0              0.0              0.0
# Sample5a                0.0              0.0              0.0
# Sample5b                0.0              0.0              0.0
# Sample6a                0.0              0.0              0.0
# ...                     ...              ...              ...
# Sample95b               0.0              0.0              0.0
# Sample96b               0.0              0.0              0.0
# Sample96a               0.0              0.0              0.0
# Sample98a               0.0              0.0              0.0
# Sample98b               0.0              0.0              0.0
#
# [70 rows x 929 columns]

# %%
[x for x in list(taxonomy_covid[['Sample73a', 'Sample63a']][taxonomy_covid['Sample73a'] != taxonomy_covid['Sample63a']].index) if x in non_healthy_features]
# Out:
# []

# %%
test_transformed = transform_data(taxonomy_covid, [], non_healthy_features)

# %%
test_transformed.T[['Sample73a', 'Sample63a']]
# Out:
#                                    Sample73a     Sample63a
# Hungatella_hathewayi           -3.324845e-01 -3.324845e-01
# Ruminococcus_gnavus            -4.305115e-01 -4.305115e-01
# Blautia_producta                7.105427e-15  7.105427e-15
# Faecalimonas_umbilicata        -2.093250e-01 -2.093250e-01
# Bacteroides_fragilis           -6.838882e-01 -6.838882e-01
# Blautia_caecimuris             -1.712313e-01 -1.712313e-01
# Flavonifractor_plautii         -1.714876e-01 -1.714876e-01
# Clostridium_butyricum          -2.108289e-01 -2.108289e-01
# Escherichia_coli               -5.865085e-01 -5.865085e-01
# Klebsiella_pneumoniae          -2.456241e-01 -2.456241e-01
# Clostridium_symbiosum           7.105427e-15  7.105427e-15
# Erysipelatoclostridium_ramosum -2.761688e-01 -2.761688e-01
# Enterocloster_aldenensis       -1.203859e-01 -1.203859e-01
# Anaerostipes_caccae             7.105427e-15  7.105427e-15
# Enterocloster_bolteae          -4.080962e-01 -4.080962e-01
# Enterocloster_clostridioformis -3.325076e-01 -3.325076e-01
# Dialister_invisus              -3.583779e-01 -3.583779e-01

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in pca.transform(test_transformed):
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results = pd.DataFrame(zip(test_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
threshold_combined
# Out:
# 1.6919901191461653

# %%
results.to_csv('results_covid.csv', index = False)

# %%
_, _, results_covid_taxonomy = hiPCA(taxonomy_covid, [], [], non_healthy_features = non_healthy_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 _, _, results_covid_taxonomy = hiPCA(taxonomy_covid, [], [], non_healthy_features = non_healthy_features)
#
# Input In [37], in hiPCA(df, healthy, non_health, df_ks, healthy_features, non_healthy_features, ks, method, p_val, only_nonhealthy_features)
#       8     selected = transform_data(df, healthy_features, non_healthy_features)
#      10 # print(selected)
# ---> 11 pca_data, pca = get_pca_data(selected.T[healthy].T)
#      12 D, principal_components, results_hotelling, t2_threshold = hotelling_t2(selected, pca, pca_data)
#      13 C, Theta1, Theta2, results_q, Q_alpha = Q_statistic(selected, pca, pca_data)
#
# Input In [33], in get_pca_data(df)
#       1 def get_pca_data(df):
#       2     pca = PCA()
# ----> 4     pca.fit(df)
#       6     eigenvalues = pca.explained_variance_
#       7     eigenvectors = pca.components_
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:456, in PCA._fit(self, X)
#     450 if issparse(X):
#     451     raise TypeError(
#     452         "PCA does not support sparse input. See "
#     453         "TruncatedSVD for a possible alternative."
#     454     )
# --> 456 X = self._validate_data(
#     457     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458 )
#     460 # Handle n_components==None
#     461 if self.n_components is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:909, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     907     n_samples = _num_samples(array)
#     908     if n_samples < ensure_min_samples:
# --> 909         raise ValueError(
#     910             "Found array with %d sample(s) (shape=%s) while a"
#     911             " minimum of %d is required%s."
#     912             % (n_samples, array.shape, ensure_min_samples, context)
#     913         )
#     915 if ensure_min_features > 0 and array.ndim == 2:
#     916     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 20)) while a minimum of 1 is required by PCA.

# %%
results_covid_taxonomy.to_csv('../../output/hiPCA/kshiPCA_covid_taxonomy.csv', index = False)

# %% [markdown]
# ### Experiment 2

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/zhu_ks92_unhealthy_species.txt', sep="\t")

# %%
healthy_features, non_healthy_features, results = hiPCA(taxonomy, healthy, non_healthy, non_healthy_features = list(unhealthy_tax['species']))
# Out:
# # Principal Components selected: 23
# 1.7667854515701797

# %%
hiPCA_zhutax = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])
hiPCA_zhutax_t2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])
hiPCA_zhutax_q = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'hiPCA with Zhu taxa (T^2): {hiPCA_zhutax_t2}')
print(f'hiPCA with Zhu taxa (Q): {hiPCA_zhutax_q}')
print(f'hiPCA with Zhu taxa (Combined): {hiPCA_zhutax}')
# Out:
# Given hiPCA: 0.6726198083067092
# hiPCA with Zhu taxa (T^2): 0.6213152289669861
# hiPCA with Zhu taxa (Q): 0.5809850905218318
# hiPCA with Zhu taxa (Combined): 0.6632268370607028

# %%
_, _, results_covid_taxonomy = hiPCA(taxonomy_covid, [], [], non_healthy_features = list(unhealthy_tax['species']) )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 _, _, results_covid_taxonomy = hiPCA(taxonomy_covid, [], [], non_healthy_features = list(unhealthy_tax['species']) )
#
# Input In [37], in hiPCA(df, healthy, non_health, df_ks, healthy_features, non_healthy_features, ks, method, p_val, only_nonhealthy_features)
#       8     selected = transform_data(df, healthy_features, non_healthy_features)
#      10 # print(selected)
# ---> 11 pca_data, pca = get_pca_data(selected.T[healthy].T)
#      12 D, principal_components, results_hotelling, t2_threshold = hotelling_t2(selected, pca, pca_data)
#      13 C, Theta1, Theta2, results_q, Q_alpha = Q_statistic(selected, pca, pca_data)
#
# Input In [33], in get_pca_data(df)
#       1 def get_pca_data(df):
#       2     pca = PCA()
# ----> 4     pca.fit(df)
#       6     eigenvalues = pca.explained_variance_
#       7     eigenvectors = pca.components_
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:456, in PCA._fit(self, X)
#     450 if issparse(X):
#     451     raise TypeError(
#     452         "PCA does not support sparse input. See "
#     453         "TruncatedSVD for a possible alternative."
#     454     )
# --> 456 X = self._validate_data(
#     457     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458 )
#     460 # Handle n_components==None
#     461 if self.n_components is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:909, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     907     n_samples = _num_samples(array)
#     908     if n_samples < ensure_min_samples:
# --> 909         raise ValueError(
#     910             "Found array with %d sample(s) (shape=%s) while a"
#     911             " minimum of %d is required%s."
#     912             % (n_samples, array.shape, ensure_min_samples, context)
#     913         )
#     915 if ensure_min_features > 0 and array.ndim == 2:
#     916     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 42)) while a minimum of 1 is required by PCA.

# %%
results_covid_taxonomy.to_csv('../../output/hiPCA/hiPCAzhutax_covid.csv', index = False)

# %% [markdown]
# ### Experiment 3

# %% [markdown]
# We tried to fit differentially expressed genes with FDR 0.05

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/differential_expression1.txt', sep="\t")

# %%
healthy_features, non_healthy_features, results = hiPCA(taxonomy, healthy, non_healthy, non_healthy_features = list(unhealthy_tax['species']))
# Out:
# # Principal Components selected: 10
# 1.689442624423493

# %%
hiPCA_zhutax = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])
hiPCA_zhutax_t2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])
hiPCA_zhutax_q = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'hiPCA with Zhu taxa (T^2): {hiPCA_zhutax_t2}')
print(f'hiPCA with Zhu taxa (Q): {hiPCA_zhutax_q}')
print(f'hiPCA with Zhu taxa (Combined): {hiPCA_zhutax}')
# Out:
# Given hiPCA: 0.6726198083067092
# hiPCA with Zhu taxa (T^2): 0.7381842385516506
# hiPCA with Zhu taxa (Q): 0.7076091586794462
# hiPCA with Zhu taxa (Combined): 0.7345580404685836

# %% [markdown]
# ### Experiment 4

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/differential_expression2.txt', sep="\t")

# %%
healthy_features, non_healthy_features, results = hiPCA(taxonomy, healthy, non_healthy, non_healthy_features = list(unhealthy_tax['species']))
# Out:
# # Principal Components selected: 9
# 1.679500808042783

# %%
hiPCA_zhutax = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])
hiPCA_zhutax_t2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])
hiPCA_zhutax_q = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'hiPCA with Zhu taxa (T^2): {hiPCA_zhutax_t2}')
print(f'hiPCA with Zhu taxa (Q): {hiPCA_zhutax_q}')
print(f'hiPCA with Zhu taxa (Combined): {hiPCA_zhutax}')
# Out:
# Given hiPCA: 0.6726198083067092
# hiPCA with Zhu taxa (T^2): 0.692209797657082
# hiPCA with Zhu taxa (Q): 0.725457933972311
# hiPCA with Zhu taxa (Combined): 0.7264323748668797

# %% [markdown]
# ### Experiment 5

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/consensus_ks_differential_expression.txt', sep="\t")

# %%
healthy_features, non_healthy_features, results = hiPCA(taxonomy, healthy, non_healthy, non_healthy_features = list(unhealthy_tax['species']))
# Out:
# # Principal Components selected: 3

# %%
hiPCA_zhutax = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])
hiPCA_zhutax_t2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])
hiPCA_zhutax_q = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'hiPCA with Zhu taxa (T^2): {hiPCA_zhutax_t2}')
print(f'hiPCA with Zhu taxa (Q): {hiPCA_zhutax_q}')
print(f'hiPCA with Zhu taxa (Combined): {hiPCA_zhutax}')
# Out:
# Given hiPCA: 0.6726198083067092
# hiPCA with Zhu taxa (T^2): 0.6928434504792332
# hiPCA with Zhu taxa (Q): 0.6681096911608093
# hiPCA with Zhu taxa (Combined): 0.6958200212992545

# %% [markdown]
# ### Experiment 6

# %%
new_taxa = pd.read_csv('../../DataSets/INDEX/hiPCA/tax_hmp2.csv', sep = '\t', index_col = 0)

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/ks_camda_species.txt', sep="\t")

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/zhu_ks92_unhealthy_species.txt', sep="\t")

# %%
healthy_features, non_healthy_features, results = hiPCA(new_taxa, [], new_taxa.columns, non_healthy_features = list(unhealthy_tax['species']), only_nonhealthy_features = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 healthy_features, non_healthy_features, results = hiPCA(new_taxa, [], new_taxa.columns, non_healthy_features = list(unhealthy_tax['species']), only_nonhealthy_features = True)
#
# Input In [37], in hiPCA(df, healthy, non_health, df_ks, healthy_features, non_healthy_features, ks, method, p_val, only_nonhealthy_features)
#       8     selected = transform_data(df, healthy_features, non_healthy_features)
#      10 # print(selected)
# ---> 11 pca_data, pca = get_pca_data(selected.T[healthy].T)
#      12 D, principal_components, results_hotelling, t2_threshold = hotelling_t2(selected, pca, pca_data)
#      13 C, Theta1, Theta2, results_q, Q_alpha = Q_statistic(selected, pca, pca_data)
#
# Input In [33], in get_pca_data(df)
#       1 def get_pca_data(df):
#       2     pca = PCA()
# ----> 4     pca.fit(df)
#       6     eigenvalues = pca.explained_variance_
#       7     eigenvectors = pca.components_
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:456, in PCA._fit(self, X)
#     450 if issparse(X):
#     451     raise TypeError(
#     452         "PCA does not support sparse input. See "
#     453         "TruncatedSVD for a possible alternative."
#     454     )
# --> 456 X = self._validate_data(
#     457     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458 )
#     460 # Handle n_components==None
#     461 if self.n_components is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:909, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     907     n_samples = _num_samples(array)
#     908     if n_samples < ensure_min_samples:
# --> 909         raise ValueError(
#     910             "Found array with %d sample(s) (shape=%s) while a"
#     911             " minimum of %d is required%s."
#     912             % (n_samples, array.shape, ensure_min_samples, context)
#     913         )
#     915 if ensure_min_features > 0 and array.ndim == 2:
#     916     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 63)) while a minimum of 1 is required by PCA.

# %%
results[results['Prediction Combined'] == 'Unhealthy']

# %%
hiPCA_zhutax = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])
hiPCA_zhutax_t2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])
hiPCA_zhutax_q = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %% [markdown]
# ### Experiment 3

# %% [markdown]
# Now we tried to fit pathways data to the KS - hiPCA

# %%
pathways = pd.read_csv('../../DataSets/CAMDA/pathways.txt', sep = '\t', index_col = 0)

# %%
pathways = pathways.T[[x for x in pathways.index if 'UNINTEGRATED' not in x]]
pathways = pathways.T

# %%
good_samples = []
for c in taxonomy.columns:
    if sum(taxonomy[c]) > 90:
        good_samples.append(c)
pathways_aux = pathways[good_samples]

# %%
ob = list(metadata[metadata['Diagnosis'] == 'Obese']['SampleID'])

# %%
healthy = list(metadata[metadata['Diagnosis'] == 'Healthy']['SampleID'])
non_healthy = list(metadata[metadata['Diagnosis'] != 'Healthy']['SampleID'])
non_healthy = [x for x in non_healthy if x not in ob]

# %%
pathways_healthy = pathways[[x for x in pathways_aux.columns if x in healthy]].T
pathways_nonhealthy = pathways[[x for x in pathways_aux.columns if x in non_healthy]].T

# %%
label = []
for item in pathways_aux.columns:
    if metadata[metadata['SampleID'] == item]['Diagnosis'].iloc[0] == 'Healthy':
        label.append('Healthy')
    else:
        label.append('Unhealthy')

# %%
X_train, X_test, y_train, y_test = train_test_split(pathways_aux.T, label, test_size=0.20, random_state=20, stratify = label)

# %%
healthy_features, non_healthy_features, pca, pca_data, D, t2_threshold, C, Q_alpha, fi, threshold_combined, selected = hiPCA3(X_train.T, healthy, non_healthy, df_ks = X_train.T, ks = True, only_nonhealthy_features = False, method = 'asymp', p_val = 0.001)
# Out:
# # Healthy features selected by KS: 1016
# # Unheatlhy features selected by KS: 659
# # Principal Components selected: 26
# 0.95 26
# 38.885138659830055
# 38.885138659830055 118.03589503853671 2.78015192791155

# %%
test_transformed = transform_data(X_test.T, [], non_healthy_features)

# %%
test_transformed = transform_data(X_test.T, healthy_features, non_healthy_features)

# %%
T2, Q, combined = [], [], []
pred_t2, pred_Q, pred_combined = [], [], []
    

for item in np.array(test_transformed):
    # print(item)
    index = item.T @ D @ item
    index2 = item.T @ C @ item
    index3 = item.T @ fi @ item
    T2.append(index)
    Q.append(index2)
    combined.append(index3)
    if index > t2_threshold:
        pred_t2.append('Unhealthy')
    else:
        pred_t2.append('Healthy')
    
    if index2 > Q_alpha:
        pred_Q.append('Unhealthy')
    else:
        pred_Q.append('Healthy')
        
    if index3 > threshold_combined:
        pred_combined.append('Unhealthy')
    else:
        pred_combined.append('Healthy') 
        
results = pd.DataFrame(zip(test_transformed.index, T2, pred_t2, Q, pred_Q, combined, pred_combined), columns = ['SampleID', 'T2', 'Prediction T2', 'Q', 'Prediction Q', 'Combined Index', 'Combined Prediction'])

# %%
balanced_accuracy_score(results['Combined Prediction'], list(y_test))
# Out:
# 0.7357549857549857

# %%
balanced_accuracy_score(results['Prediction T2'], list(y_test))
# Out:
# 0.6480562448304383

# %%
balanced_accuracy_score(results['Prediction Q'], list(y_test))
# Out:
# 0.6670020120724346

# %%
ks_hiPCA_path = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results_pathways['Prediction Combined'])
ks_hiPCA_patht2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results_pathways['Prediction T2'])
ks_hiPCA_pathq = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results_pathways['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'hiPCA with pathways (T^2): {ks_hiPCA_patht2}')
print(f'hiPCA with pathways (Q): {ks_hiPCA_pathq}')
print(f'hiPCA with pathways (Combined): {ks_hiPCA_path}')
# Out:
# Given hiPCA: 0.6726198083067092
# hiPCA with pathways (T^2): 0.7018690095846645
# hiPCA with pathways (Q): 0.5
# hiPCA with pathways (Combined): 0.5

# %%
pathways_covid = pd.read_csv('../../DataSets/COVID/CAMDA_pathways.txt', sep = '\t', index_col = 0)

# %%
_, _, results_hotelling_covid, results_q_covid, results_hiPCA_covid = hiPCA(pathways_covid, [], [], healthy_features = healthy_features, non_healthy_features = non_healthy_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [278], in <cell line: 1>()
# ----> 1 _, _, results_hotelling_covid, results_q_covid, results_hiPCA_covid = hiPCA(pathways_covid, [], [], healthy_features = healthy_features, non_healthy_features = non_healthy_features)
#
# Input In [37], in hiPCA(df, healthy, non_health, df_ks, healthy_features, non_healthy_features, ks, method, p_val, only_nonhealthy_features)
#       8     selected = transform_data(df, healthy_features, non_healthy_features)
#      10 # print(selected)
# ---> 11 pca_data, pca = get_pca_data(selected.T[healthy].T)
#      12 D, principal_components, results_hotelling, t2_threshold = hotelling_t2(selected, pca, pca_data)
#      13 C, Theta1, Theta2, results_q, Q_alpha = Q_statistic(selected, pca, pca_data)
#
# Input In [33], in get_pca_data(df)
#       1 def get_pca_data(df):
#       2     pca = PCA()
# ----> 4     pca.fit(df)
#       6     eigenvalues = pca.explained_variance_
#       7     eigenvectors = pca.components_
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:408, in PCA.fit(self, X, y)
#     385 """Fit the model with X.
#     386
#     387 Parameters
#    (...)
#     399     Returns the instance itself.
#     400 """
#     401 check_scalar(
#     402     self.n_oversamples,
#     403     "n_oversamples",
#     404     min_val=1,
#     405     target_type=numbers.Integral,
#     406 )
# --> 408 self._fit(X)
#     409 return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:456, in PCA._fit(self, X)
#     450 if issparse(X):
#     451     raise TypeError(
#     452         "PCA does not support sparse input. See "
#     453         "TruncatedSVD for a possible alternative."
#     454     )
# --> 456 X = self._validate_data(
#     457     X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     458 )
#     460 # Handle n_components==None
#     461 if self.n_components is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     575     raise ValueError("Validation should be done on X, y or both.")
#     576 elif not no_val_X and no_val_y:
# --> 577     X = check_array(X, input_name="X", **check_params)
#     578     out = X
#     579 elif no_val_X and not no_val_y:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:768, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     764     pandas_requires_conversion = any(
#     765         _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     766     )
#     767     if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 768         dtype_orig = np.result_type(*dtypes_orig)
#     770 if dtype_numeric:
#     771     if dtype_orig is not None and dtype_orig.kind == "O":
#     772         # if input is object, convert to float.
#
# File <__array_function__ internals>:180, in result_type(*args, **kwargs)
#
# ValueError: at least one array or dtype is required

# %% [markdown]
# ### Experiment

# %%
unhealthy_tax = pd.read_csv('../../DataSets/INDEX/hiPCA/differential_expression1.txt', sep="\t")

# %%
healthy_features, non_healthy_features, results = hiPCA(taxonomy, healthy, non_healthy, non_healthy_features = list(unhealthy_tax['species']))
# Out:
# # Principal Components selected: 10
# 1.689442624423493

# %%
hiPCA_zhutax = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Combined'])
hiPCA_zhutax_t2 = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction T2'])
hiPCA_zhutax_q = balanced_accuracy_score(['Unhealthy' if x != 'Healthy' else 'Healthy' for x in metadata[metadata['SampleID'].isin(taxonomy.columns)]['Diagnosis']],results['Prediction Q'])

# %%
print(f'Given hiPCA: {original_hiPCA}')
print(f'hiPCA with Zhu taxa (T^2): {hiPCA_zhutax_t2}')
print(f'hiPCA with Zhu taxa (Q): {hiPCA_zhutax_q}')
print(f'hiPCA with Zhu taxa (Combined): {hiPCA_zhutax}')
# Out:
# Given hiPCA: 0.6726198083067092
# hiPCA with Zhu taxa (T^2): 0.7381842385516506
# hiPCA with Zhu taxa (Q): 0.7076091586794462
# hiPCA with Zhu taxa (Combined): 0.7345580404685836

# %%
unhealthy_functions = pd.read_csv('../../DataSets/INDEX/hiPCA/Function_UnHealthy_CD&OB&UC.txt', sep="\t")

# %%
pathways = pd.read_csv('../../DataSets/CAMDA/pathways.txt', sep = '\t', index_col = 0)

# %%
# pathways = pathways.T[list(unhealthy_functions['UnHealthy_CD&OB&UC'])]

# %%
X_train.index
# Out:
# Index(['SRR5946790', 'SRR5936223', 'SRR5946723', 'SRR5983412', 'SRR5946617',
#        'ERR209226', 'SRR5946708', 'SRR5947008', 'SRR5946861', 'ERR209782',
#        ...
#        'ERR209746', 'SRR5946684', 'ERR209440', 'SRR5936014', 'SRR5983333',
#        'SRR5936173', 'SRR5946989', 'SRR5947057', 'SRR5947000', 'ERR209287'],
#       dtype='object', length=422)

# %%
pathways_train = pathways[list(X_train.index)]

# %%
pathways_train = pathways_train.T

# %%
pathways_train
# Out:
# # Pathway   UNINTEGRATED|g__Absiella.s__Absiella_dolichum  \
# SRR5946702                                            0.0
# SRR5935764                                            0.0
# SRR5936213                                            0.0
# SRR5946708                                            0.0
# SRR5936199                                            0.0
# ...                                                   ...
# SRR5946821                                            0.0
# SRR5935889                                            0.0
# SRR5946660                                            0.0
# SRR5947101                                            0.0
# SRR5947813                                            0.0
#
# # Pathway   UNINTEGRATED|g__Acetobacter.s__Acetobacter_sp_CAG_267  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Acetobacter.s__Acetobacter_sp_CAG_977  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Acholeplasma.s__Acholeplasma_sp_CAG_878  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Acidaminococcus.s__Acidaminococcus_intestini  \
# SRR5946702                                           0.000000
# SRR5935764                                           0.000000
# SRR5936213                                           0.000000
# SRR5946708                                           0.000000
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.002044
# SRR5946660                                           0.000000
# SRR5947101                                           0.000000
# SRR5947813                                           0.000000
#
# # Pathway   UNINTEGRATED|g__Acinetobacter.s__Acinetobacter_idrijaensis  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Acinetobacter.s__Acinetobacter_lwoffii  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_HMSC035G02  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_HPA0247  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_ICM47  ...  \
# SRR5946702                                                0.0    ...
# SRR5935764                                                0.0    ...
# SRR5936213                                                0.0    ...
# SRR5946708                                                0.0    ...
# SRR5936199                                                0.0    ...
# ...                                                       ...    ...
# SRR5946821                                                0.0    ...
# SRR5935889                                                0.0    ...
# SRR5946660                                                0.0    ...
# SRR5947101                                                0.0    ...
# SRR5947813                                                0.0    ...
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_atypica  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_denticariosi  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_dispar  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_infantium  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_parvula  \
# SRR5946702                                           0.000000
# SRR5935764                                           0.000000
# SRR5936213                                           0.000000
# SRR5946708                                           0.000000
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000101
# SRR5935889                                           0.000000
# SRR5946660                                           0.000000
# SRR5947101                                           0.000000
# SRR5947813                                           0.000000
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_rogosae  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_seminalis  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_tobetsuensis  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Victivallales_unclassified.s__Victivallales_bacterium_CCUG_44730  \
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Victivallis.s__Victivallis_vadensis
# SRR5946702                                                0.0
# SRR5935764                                                0.0
# SRR5936213                                                0.0
# SRR5946708                                                0.0
# SRR5936199                                                0.0
# ...                                                       ...
# SRR5946821                                                0.0
# SRR5935889                                                0.0
# SRR5946660                                                0.0
# SRR5947101                                                0.0
# SRR5947813                                                0.0
#
# [401 rows x 25519 columns]

# %%
# labels_pathways = []
# for item in pathways.index:
#     if metadata[metadata['SampleID'] == item]['Diagnosis'].iloc[0] == 'Healthy':
#         labels_pathways.append('Healthy')
#     else:
#         labels_pathways.append('Unhealthy')

# %%
pathways_train
# Out:
# # Pathway   UNINTEGRATED|g__Absiella.s__Absiella_dolichum  \
# SRR5946790                                            0.0
# SRR5936223                                            0.0
# SRR5946723                                            0.0
# SRR5983412                                            0.0
# SRR5946617                                            0.0
# ...                                                   ...
# SRR5936173                                            0.0
# SRR5946989                                            0.0
# SRR5947057                                            0.0
# SRR5947000                                            0.0
# ERR209287                                             0.0
#
# # Pathway   UNINTEGRATED|g__Acetobacter.s__Acetobacter_sp_CAG_267  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acetobacter.s__Acetobacter_sp_CAG_977  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acholeplasma.s__Acholeplasma_sp_CAG_878  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acidaminococcus.s__Acidaminococcus_intestini  \
# SRR5946790                                            0.00000
# SRR5936223                                            0.00000
# SRR5946723                                            0.00000
# SRR5983412                                            0.00000
# SRR5946617                                            0.00000
# ...                                                       ...
# SRR5936173                                            0.00000
# SRR5946989                                            0.00000
# SRR5947057                                            0.00000
# SRR5947000                                            0.00176
# ERR209287                                             0.00000
#
# # Pathway   UNINTEGRATED|g__Acinetobacter.s__Acinetobacter_idrijaensis  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Acinetobacter.s__Acinetobacter_lwoffii  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_HMSC035G02  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_HPA0247  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   UNINTEGRATED|g__Actinomyces.s__Actinomyces_sp_ICM47  ...  \
# SRR5946790                                                0.0    ...
# SRR5936223                                                0.0    ...
# SRR5946723                                                0.0    ...
# SRR5983412                                                0.0    ...
# SRR5946617                                                0.0    ...
# ...                                                       ...    ...
# SRR5936173                                                0.0    ...
# SRR5946989                                                0.0    ...
# SRR5947057                                                0.0    ...
# SRR5947000                                                0.0    ...
# ERR209287                                                 0.0    ...
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_atypica  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_denticariosi  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_dispar  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_infantium  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_parvula  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_rogosae  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_seminalis  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Veillonella.s__Veillonella_tobetsuensis  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Victivallales_unclassified.s__Victivallales_bacterium_CCUG_44730  \
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# # Pathway   VALSYN-PWY: L-valine biosynthesis|g__Victivallis.s__Victivallis_vadensis
# SRR5946790                                                0.0
# SRR5936223                                                0.0
# SRR5946723                                                0.0
# SRR5983412                                                0.0
# SRR5946617                                                0.0
# ...                                                       ...
# SRR5936173                                                0.0
# SRR5946989                                                0.0
# SRR5947057                                                0.0
# SRR5947000                                                0.0
# ERR209287                                                 0.0
#
# [422 rows x 25519 columns]

# %%
len(X_train)
# Out:
# 422

# %%
# len(y_train), len(labels_pathways)
# Out:
# (422, 401)

# %%
des = pathways_train.describe()

# %%
des.T.sort_values('std', ascending = False)
# Out:
#                                                     count      mean       std  \
# # Pathway
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_vulg...  401.0  0.098312  0.129089
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_frag...  401.0  0.032614  0.075339
# UNINTEGRATED|g__Escherichia.s__Escherichia_coli     401.0  0.023515  0.071707
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_unif...  401.0  0.057475  0.067895
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_dorei    401.0  0.027658  0.064966
# ...                                                   ...       ...       ...
# PWY-6385: peptidoglycan biosynthesis III (mycob...  401.0  0.000000  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  401.0  0.000000  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  401.0  0.000000  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  401.0  0.000000  0.000000
# VALSYN-PWY: L-valine biosynthesis|g__Victivalli...  401.0  0.000000  0.000000
#
#                                                     min  25%       50%  \
# # Pathway
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_vulg...  0.0  0.0  0.039231
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_frag...  0.0  0.0  0.000000
# UNINTEGRATED|g__Escherichia.s__Escherichia_coli     0.0  0.0  0.000000
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_unif...  0.0  0.0  0.040042
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_dorei    0.0  0.0  0.000000
# ...                                                 ...  ...       ...
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.0  0.0  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.0  0.0  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.0  0.0  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.0  0.0  0.000000
# VALSYN-PWY: L-valine biosynthesis|g__Victivalli...  0.0  0.0  0.000000
#
#                                                          75%       max
# # Pathway
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_vulg...  0.153935  0.978464
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_frag...  0.026146  0.492118
# UNINTEGRATED|g__Escherichia.s__Escherichia_coli     0.003824  0.578823
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_unif...  0.091119  0.634088
# UNINTEGRATED|g__Bacteroides.s__Bacteroides_dorei    0.021344  0.482179
# ...                                                      ...       ...
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.000000  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.000000  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.000000  0.000000
# PWY-6385: peptidoglycan biosynthesis III (mycob...  0.000000  0.000000
# VALSYN-PWY: L-valine biosynthesis|g__Victivalli...  0.000000  0.000000
#
# [25519 rows x 8 columns]

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
info = mutual_info_classif(pathways_train, y_train)
# Out:
# KeyboardInterrupt

# %%
from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split

# %%
# X_train, X_test, y_train, y_test = train_test_split(pathways, label, test_size=0.20, stratify = label, random_state=21)

# %%
clf = RandomForestClassifier(max_depth=10, min_samples_leaf=3, random_state=0)

# %%
clf.fit(pathways_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=3, random_state=0)

# %%
from sklearn.metrics import balanced_accuracy_score
pred = clf.predict(pathways[list(X_test.index)].T)
balanced_accuracy_score(y_test, pred)
# Out:
# 0.8504709576138147

# %%
selected_pathways = list(pd.DataFrame(zip(pathways_train.columns, clf.feature_importances_)).sort_values(1, ascending = False)[:39][0])

# %%
# results['Combined']

# %%
selected_pathways
# Out:
# ['PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  "PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis",
#  'PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis',
#  'DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis',
#  'NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis',
#  'UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii',
#  'PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis',
#  'UNINTEGRATED|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-7851: coenzyme A biosynthesis II (eukaryotic)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-7242: D-fructuronate degradation|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'UNINTEGRATED|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-6122: 5-aminoimidazole ribonucleotide biosynthesis II|g__Alistipes.s__Alistipes_putredinis',
#  'GLUCUROCAT-PWY: superpathway of &beta;-D-glucuronosides degradation|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  "PWY-7234: inosine-5'-phosphate biosynthesis III|g__Alistipes.s__Alistipes_putredinis",
#  'UNINTEGRATED|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6609: adenine and adenosine salvage III|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_onderdonkii',
#  'PWY-5130: 2-oxobutanoate degradation I|g__Alistipes.s__Alistipes_putredinis',
#  '1CMET2-PWY: folate transformations III (E. coli)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-7953: UDP-N-acetylmuramoyl-pentapeptide biosynthesis III (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis',
#  'COA-PWY: coenzyme A biosynthesis I (prokaryotic)|g__Alistipes.s__Alistipes_finegoldii',
#  'TRNA-CHARGING-PWY: tRNA charging|g__Alistipes.s__Alistipes_putredinis',
#  'CALVIN-PWY: Calvin-Benson-Bassham cycle|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_finegoldii',
#  'PWY-6387: UDP-N-acetylmuramoyl-pentapeptide biosynthesis I (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis',
#  "PWY-6124: inosine-5'-phosphate biosynthesis II|g__Alistipes.s__Alistipes_putredinis",
#  'UNINTEGRATED|g__Klebsiella.s__Klebsiella_oxytoca',
#  'PWY-6122: 5-aminoimidazole ribonucleotide biosynthesis II|g__Hungatella.s__Hungatella_hathewayi',
#  'PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis',
#  'GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  "PWY-5695: inosine 5'-phosphate degradation|g__Alistipes.s__Alistipes_finegoldii",
#  'ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6317: D-galactose degradation I (Leloir pathway)|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6700: queuosine biosynthesis I (de novo)|g__Parabacteroides.s__Parabacteroides_merdae',
#  'PWY-7791: UMP biosynthesis III|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Flavonifractor.s__Flavonifractor_plautii',
#  'PWY-5667: CDP-diacylglycerol biosynthesis I|g__Hungatella.s__Hungatella_hathewayi']

# %%
selected = pathways_train[selected_pathways]

# %%
selected['hiPCA'] = list(results_train['Combined Index'])
# Out:
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2666387670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected['hiPCA'] = list(results_train['Combined Index'])

# %%
selected['hiPCA'] = selected['hiPCA'] - threshold_combined
# Out:
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\1355578616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected['hiPCA'] = selected['hiPCA'] - threshold_combined

# %%
selected
# Out:
# # Pathway   GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# SRR5946702                                           0.000027
# SRR5935764                                           0.000127
# SRR5936213                                           0.000090
# SRR5946708                                           0.000076
# SRR5936199                                           0.000057
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000015
# SRR5946660                                           0.000012
# SRR5947101                                           0.000006
# SRR5947813                                           0.000015
#
# # Pathway   PWY-7234: inosine-5'-phosphate biosynthesis III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000019
# SRR5935764                                           0.000000
# SRR5936213                                           0.000042
# SRR5946708                                           0.000015
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000014
# SRR5946660                                           0.000022
# SRR5947101                                           0.000000
# SRR5947813                                           0.000020
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000022
# SRR5935764                                           0.000000
# SRR5936213                                           0.000039
# SRR5946708                                           0.000014
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000010
# SRR5946660                                           0.000022
# SRR5947101                                           0.000000
# SRR5947813                                           0.000018
#
# # Pathway   PWY-5103: L-isoleucine biosynthesis III|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5946702                                           0.000007
# SRR5935764                                           0.000015
# SRR5936213                                           0.000000
# SRR5946708                                           0.000017
# SRR5936199                                           0.000010
# ...                                                       ...
# SRR5946821                                           0.000015
# SRR5935889                                           0.000011
# SRR5946660                                           0.000007
# SRR5947101                                           0.000005
# SRR5947813                                           0.000006
#
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5946702                                           0.000005
# SRR5935764                                           0.000016
# SRR5936213                                           0.000000
# SRR5946708                                           0.000009
# SRR5936199                                           0.000008
# ...                                                       ...
# SRR5946821                                           0.000008
# SRR5935889                                           0.000009
# SRR5946660                                           0.000006
# SRR5947101                                           0.000004
# SRR5947813                                           0.000004
#
# # Pathway   PWY-5030: L-histidine degradation III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000018
# SRR5935764                                           0.000000
# SRR5936213                                           0.000042
# SRR5946708                                           0.000014
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000009
# SRR5946660                                           0.000022
# SRR5947101                                           0.000000
# SRR5947813                                           0.000020
#
# # Pathway   TRNA-CHARGING-PWY: tRNA charging|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000021
# SRR5935764                                           0.000000
# SRR5936213                                           0.000041
# SRR5946708                                           0.000016
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000012
# SRR5946660                                           0.000025
# SRR5947101                                           0.000000
# SRR5947813                                           0.000021
#
# # Pathway   PWY-1042: glycolysis IV|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5946702                                           0.000006
# SRR5935764                                           0.000014
# SRR5936213                                           0.000000
# SRR5946708                                           0.000017
# SRR5936199                                           0.000011
# ...                                                       ...
# SRR5946821                                           0.000011
# SRR5935889                                           0.000012
# SRR5946660                                           0.000006
# SRR5947101                                           0.000004
# SRR5947813                                           0.000006
#
# # Pathway   PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000017
# SRR5935764                                           0.000000
# SRR5936213                                           0.000037
# SRR5946708                                           0.000012
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000010
# SRR5946660                                           0.000021
# SRR5947101                                           0.000000
# SRR5947813                                           0.000021
#
# # Pathway   PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000018
# SRR5935764                                           0.000000
# SRR5936213                                           0.000039
# SRR5946708                                           0.000015
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000013
# SRR5946660                                           0.000025
# SRR5947101                                           0.000000
# SRR5947813                                           0.000021
#
# # Pathway   ...  \
# SRR5946702  ...
# SRR5935764  ...
# SRR5936213  ...
# SRR5946708  ...
# SRR5936199  ...
# ...         ...
# SRR5946821  ...
# SRR5935889  ...
# SRR5946660  ...
# SRR5947101  ...
# SRR5947813  ...
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# SRR5946702                                           0.000031
# SRR5935764                                           0.000134
# SRR5936213                                           0.000116
# SRR5946708                                           0.000095
# SRR5936199                                           0.000089
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000029
# SRR5946660                                           0.000022
# SRR5947101                                           0.000007
# SRR5947813                                           0.000026
#
# # Pathway   PWY-5686: UMP biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000020
# SRR5935764                                           0.000000
# SRR5936213                                           0.000045
# SRR5946708                                           0.000017
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000013
# SRR5946660                                           0.000023
# SRR5947101                                           0.000000
# SRR5947813                                           0.000020
#
# # Pathway   PWY-8178: pentose phosphate pathway (non-oxidative branch) II|g__Bacteroides.s__Bacteroides_fragilis  \
# SRR5946702                                           0.000032
# SRR5935764                                           0.000000
# SRR5936213                                           0.000000
# SRR5946708                                           0.000000
# SRR5936199                                           0.000167
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000008
# SRR5946660                                           0.000000
# SRR5947101                                           0.000000
# SRR5947813                                           0.000002
#
# # Pathway   PWY-7790: UMP biosynthesis II|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000017
# SRR5935764                                           0.000000
# SRR5936213                                           0.000038
# SRR5946708                                           0.000016
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000012
# SRR5946660                                           0.000022
# SRR5947101                                           0.000000
# SRR5947813                                           0.000018
#
# # Pathway   PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000015
# SRR5935764                                           0.000000
# SRR5936213                                           0.000040
# SRR5946708                                           0.000015
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000011
# SRR5946660                                           0.000022
# SRR5947101                                           0.000000
# SRR5947813                                           0.000020
#
# # Pathway   PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Alistipes.s__Alistipes_finegoldii  \
# SRR5946702                                           0.000000
# SRR5935764                                           0.000013
# SRR5936213                                           0.000028
# SRR5946708                                           0.000004
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000019
# SRR5946660                                           0.000038
# SRR5947101                                           0.000000
# SRR5947813                                           0.000003
#
# # Pathway   PWY-7953: UDP-N-acetylmuramoyl-pentapeptide biosynthesis III (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000018
# SRR5935764                                           0.000000
# SRR5936213                                           0.000037
# SRR5946708                                           0.000014
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000011
# SRR5946660                                           0.000020
# SRR5947101                                           0.000000
# SRR5947813                                           0.000019
#
# # Pathway   NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5946702                                           0.000019
# SRR5935764                                           0.000000
# SRR5936213                                           0.000034
# SRR5946708                                           0.000015
# SRR5936199                                           0.000000
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000010
# SRR5946660                                           0.000022
# SRR5947101                                           0.000000
# SRR5947813                                           0.000018
#
# # Pathway   PWY-6151: S-adenosyl-L-methionine salvage I|g__Bacteroides.s__Bacteroides_fragilis  \
# SRR5946702                                           0.000024
# SRR5935764                                           0.000000
# SRR5936213                                           0.000000
# SRR5946708                                           0.000000
# SRR5936199                                           0.000157
# ...                                                       ...
# SRR5946821                                           0.000000
# SRR5935889                                           0.000007
# SRR5946660                                           0.000000
# SRR5947101                                           0.000000
# SRR5947813                                           0.000001
#
# # Pathway      hiPCA
# SRR5946702 -0.707453
# SRR5935764 -0.982715
# SRR5936213 -0.846744
# SRR5946708 -1.029230
# SRR5936199  2.170641
# ...              ...
# SRR5946821  2.133573
# SRR5935889 -0.843628
# SRR5946660 -0.729817
# SRR5947101 -1.054916
# SRR5947813  0.558776
#
# [401 rows x 40 columns]

# %%
pathways_test = pathways.T[selected_pathways]
pathways_test = pathways_test.T[X_test.index].T
pathways_test['hiPCA'] = list(results['Combined Index'])
pathways_test['hiPCA'] = pathways_test['hiPCA'] - threshold_combined

# %%
pathways_test.head()
# Out:
# # Pathway   GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# SRR5935802                                                0.0
# SRR5947102                                                0.0
# SRR5946673                                                0.0
# ERR209749                                                 0.0
# SRR5935984                                                0.0
#
# # Pathway   PWY-7234: inosine-5'-phosphate biosynthesis III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000005
# SRR5935984                                           0.000029
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000005
# SRR5935984                                           0.000027
#
# # Pathway   PWY-5103: L-isoleucine biosynthesis III|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5935802                                       0.000000e+00
# SRR5947102                                       3.929090e-06
# SRR5946673                                       0.000000e+00
# ERR209749                                        0.000000e+00
# SRR5935984                                       8.534360e-07
#
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000004
# SRR5946673                                           0.000000
# ERR209749                                            0.000000
# SRR5935984                                           0.000000
#
# # Pathway   PWY-5030: L-histidine degradation III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000004
# SRR5935984                                           0.000025
#
# # Pathway   TRNA-CHARGING-PWY: tRNA charging|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000005
# SRR5935984                                           0.000038
#
# # Pathway   PWY-1042: glycolysis IV|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000003
# SRR5946673                                           0.000000
# ERR209749                                            0.000000
# SRR5935984                                           0.000000
#
# # Pathway   PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000004
# SRR5935984                                           0.000026
#
# # Pathway   PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000004
# SRR5935984                                           0.000028
#
# # Pathway   ...  \
# SRR5935802  ...
# SRR5947102  ...
# SRR5946673  ...
# ERR209749   ...
# SRR5935984  ...
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# SRR5935802                                                0.0
# SRR5947102                                                0.0
# SRR5946673                                                0.0
# ERR209749                                                 0.0
# SRR5935984                                                0.0
#
# # Pathway   PWY-5686: UMP biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000005
# SRR5935984                                           0.000031
#
# # Pathway   PWY-8178: pentose phosphate pathway (non-oxidative branch) II|g__Bacteroides.s__Bacteroides_fragilis  \
# SRR5935802                                            0.00004
# SRR5947102                                            0.00000
# SRR5946673                                            0.00000
# ERR209749                                             0.00000
# SRR5935984                                            0.00000
#
# # Pathway   PWY-7790: UMP biosynthesis II|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000005
# SRR5935984                                           0.000031
#
# # Pathway   PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000004
# SRR5935984                                           0.000029
#
# # Pathway   PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Alistipes.s__Alistipes_finegoldii  \
# SRR5935802                                       7.818800e-06
# SRR5947102                                       0.000000e+00
# SRR5946673                                       0.000000e+00
# ERR209749                                        3.712500e-07
# SRR5935984                                       1.234270e-05
#
# # Pathway   PWY-7953: UDP-N-acetylmuramoyl-pentapeptide biosynthesis III (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000004
# SRR5935984                                           0.000023
#
# # Pathway   NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5935802                                           0.000000
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000004
# SRR5935984                                           0.000026
#
# # Pathway   PWY-6151: S-adenosyl-L-methionine salvage I|g__Bacteroides.s__Bacteroides_fragilis  \
# SRR5935802                                           0.000036
# SRR5947102                                           0.000000
# SRR5946673                                           0.000000
# ERR209749                                            0.000000
# SRR5935984                                           0.000000
#
# # Pathway      hiPCA
# SRR5935802  1.331055
# SRR5947102  1.367050
# SRR5946673  3.247998
# ERR209749   2.439433
# SRR5935984 -0.271193
#
# [5 rows x 40 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
for c in selected.columns:
    scaler.fit(np.array(selected[c]).reshape(-1, 1))
    selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
    pathways_test[c] = scaler.transform(np.array(pathways_test[c]).reshape(-1, 1))
# Out:
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))
# C:\Users\rafap\AppData\Local\Temp\ipykernel_23444\2916237542.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected[c] = scaler.transform(np.array(selected[c]).reshape(-1, 1))

# %%
pathways_test.head()
# Out:
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000003
# SRR5983384                                           0.000001
# SRR5935963                                           0.000009
#
# # Pathway   PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000015
# SRR5935963                                           0.000010
#
# # Pathway   PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000013
# SRR5935963                                           0.000007
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000012
# SRR5935963                                           0.000008
#
# # Pathway   NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000012
# SRR5935963                                           0.000008
#
# # Pathway   PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000015
# SRR5935963                                           0.000009
#
# # Pathway   UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.001831
# SRR5983384                                           0.001306
# SRR5935963                                           0.000917
#
# # Pathway   PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000012
# SRR5935963                                           0.000009
#
# # Pathway   UNINTEGRATED|g__Hungatella.s__Hungatella_hathewayi  \
# SRR5983264                                           0.000000
# ERR209710                                            0.033351
# SRR5947057                                           0.000000
# SRR5983384                                           0.000000
# SRR5935963                                           0.000000
#
# # Pathway   PWY-7851: coenzyme A biosynthesis II (eukaryotic)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000012
# SRR5935963                                           0.000009
#
# # Pathway   ...  \
# SRR5983264  ...
# ERR209710   ...
# SRR5947057  ...
# SRR5983384  ...
# SRR5935963  ...
#
# # Pathway   PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000013
# SRR5935963                                           0.000009
#
# # Pathway   GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# SRR5983264                                           0.000012
# ERR209710                                            0.000006
# SRR5947057                                           0.000000
# SRR5983384                                           0.000003
# SRR5935963                                           0.000043
#
# # Pathway   PWY-5695: inosine 5'-phosphate degradation|g__Alistipes.s__Alistipes_finegoldii  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000004
# SRR5983384                                           0.000000
# SRR5935963                                           0.000004
#
# # Pathway   ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)|g__Hungatella.s__Hungatella_hathewayi  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000036
# SRR5947057                                           0.000000
# SRR5983384                                           0.000000
# SRR5935963                                           0.000000
#
# # Pathway   PWY-6317: D-galactose degradation I (Leloir pathway)|g__Hungatella.s__Hungatella_hathewayi  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000032
# SRR5947057                                           0.000000
# SRR5983384                                           0.000000
# SRR5935963                                           0.000000
#
# # Pathway   PWY-6700: queuosine biosynthesis I (de novo)|g__Parabacteroides.s__Parabacteroides_merdae  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000009
# SRR5983384                                           0.000000
# SRR5935963                                           0.000000
#
# # Pathway   PWY-7791: UMP biosynthesis III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000000
# SRR5947057                                           0.000000
# SRR5983384                                           0.000014
# SRR5935963                                           0.000010
#
# # Pathway   PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Flavonifractor.s__Flavonifractor_plautii  \
# SRR5983264                                                0.0
# ERR209710                                                 0.0
# SRR5947057                                                0.0
# SRR5983384                                                0.0
# SRR5935963                                                0.0
#
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Hungatella.s__Hungatella_hathewayi  \
# SRR5983264                                           0.000000
# ERR209710                                            0.000019
# SRR5947057                                           0.000000
# SRR5983384                                           0.000000
# SRR5935963                                           0.000000
#
# # Pathway      hiPCA
# SRR5983264 -0.707042
# ERR209710   2.739968
# SRR5947057 -0.566980
# SRR5983384 -0.221122
# SRR5935963 -0.824825
#
# [5 rows x 40 columns]

# %%
selected.head()
# Out:
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# ERR209799                                            0.000029
# SRR5983354                                           0.000013
# SRR5946648                                           0.000000
# ERR209854                                            0.000001
# SRR5935795                                           0.000017
#
# # Pathway   PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000011
# SRR5983354                                           0.000026
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
#
# # Pathway   PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000010
# SRR5983354                                           0.000021
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000009
# SRR5983354                                           0.000025
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
#
# # Pathway   NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000022
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
#
# # Pathway   PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000010
# SRR5983354                                           0.000032
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
#
# # Pathway   UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii  \
# ERR209799                                            0.000000
# SRR5983354                                           0.001581
# SRR5946648                                           0.000000
# ERR209854                                            0.000702
# SRR5935795                                           0.000447
#
# # Pathway   PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000010
# SRR5983354                                           0.000023
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
#
# # Pathway   UNINTEGRATED|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                                 0.0
# SRR5983354                                                0.0
# SRR5946648                                                0.0
# ERR209854                                                 0.0
# SRR5935795                                                0.0
#
# # Pathway   PWY-7851: coenzyme A biosynthesis II (eukaryotic)|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000008
# SRR5983354                                           0.000020
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
#
# # Pathway   ...  \
# ERR209799   ...
# SRR5983354  ...
# SRR5946648  ...
# ERR209854   ...
# SRR5935795  ...
#
# # Pathway   PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000022
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
#
# # Pathway   GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# ERR209799                                            0.000041
# SRR5983354                                           0.000000
# SRR5946648                                           0.000007
# ERR209854                                            0.000025
# SRR5935795                                           0.000005
#
# # Pathway   PWY-5695: inosine 5'-phosphate degradation|g__Alistipes.s__Alistipes_finegoldii  \
# ERR209799                                        0.000000e+00
# SRR5983354                                       5.285640e-06
# SRR5946648                                       0.000000e+00
# ERR209854                                        1.685320e-06
# SRR5935795                                       7.899730e-07
#
# # Pathway   ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                                 0.0
# SRR5983354                                                0.0
# SRR5946648                                                0.0
# ERR209854                                                 0.0
# SRR5935795                                                0.0
#
# # Pathway   PWY-6317: D-galactose degradation I (Leloir pathway)|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                                 0.0
# SRR5983354                                                0.0
# SRR5946648                                                0.0
# ERR209854                                                 0.0
# SRR5935795                                                0.0
#
# # Pathway   PWY-6700: queuosine biosynthesis I (de novo)|g__Parabacteroides.s__Parabacteroides_merdae  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000005
# SRR5946648                                           0.000000
# ERR209854                                            0.000002
# SRR5935795                                           0.000018
#
# # Pathway   PWY-7791: UMP biosynthesis III|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000011
# SRR5983354                                           0.000024
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
#
# # Pathway   PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Flavonifractor.s__Flavonifractor_plautii  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000000
# SRR5946648                                           0.000004
# ERR209854                                            0.000000
# SRR5935795                                           0.000000
#
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                                 0.0
# SRR5983354                                                0.0
# SRR5946648                                                0.0
# ERR209854                                                 0.0
# SRR5935795                                                0.0
#
# # Pathway      hiPCA
# ERR209799  -0.459553
# SRR5983354 -0.666178
# SRR5946648 -0.617286
# ERR209854  -0.295685
# SRR5935795 -0.238637
#
# [5 rows x 40 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
# X_train, X_test, y_train, y_test = train_test_split(selected, label, test_size=0.20, stratify = label, random_state=21)

# %%
clf = LogisticRegression(random_state=0).fit(selected, y_train)

# %%
clf.coef_
# Out:
# array([[-0.4540263 ,  0.40385164, -0.37193327, -0.03297965,  0.12524968,
#          0.26508779, -0.62004166,  0.11146052,  0.50322734, -0.13548388,
#          0.04915104, -0.56634493,  0.57041198, -0.53177851, -0.38861252,
#         -0.30814701, -0.80635278, -0.40607177, -0.44156791,  0.15420597,
#         -0.19268724,  0.57011172, -1.06843676,  0.23852674,  0.10905629,
#          0.92959702,  0.38329012,  0.54321614,  0.06411004, -0.21466933,
#          0.69264516, -0.62315825,  0.32069593,  0.2003836 , -1.00916063,
#          0.44296006,  0.3127031 ,  0.44234899,  0.43450308,  1.73735209]])

# %%
list(selected.columns)
# Out:
# ['GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  "PWY-7234: inosine-5'-phosphate biosynthesis III|g__Alistipes.s__Alistipes_putredinis",
#  'DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-5103: L-isoleucine biosynthesis III|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'PWY-5030: L-histidine degradation III|g__Alistipes.s__Alistipes_putredinis',
#  'TRNA-CHARGING-PWY: tRNA charging|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-1042: glycolysis IV|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6122: 5-aminoimidazole ribonucleotide biosynthesis II|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis',
#  "PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis",
#  'UNINTEGRATED|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'ARO-PWY: chorismate biosynthesis I|g__Parabacteroides.s__Parabacteroides_merdae',
#  'PWY-7237: myo-, chiro- and scyllo-inositol degradation|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-1042: glycolysis IV|g__Alistipes.s__Alistipes_shahii',
#  'PWY-7111: pyruvate fermentation to isobutanol (engineered)|g__Hungatella.s__Hungatella_hathewayi',
#  'TRNA-CHARGING-PWY: tRNA charging|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Alistipes.s__Alistipes_putredinis',
#  'UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii',
#  'PWY-7238: sucrose biosynthesis II|g__Hungatella.s__Hungatella_hathewayi',
#  'VALSYN-PWY: L-valine biosynthesis|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-7790: UMP biosynthesis II|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_finegoldii',
#  'PWY-5667: CDP-diacylglycerol biosynthesis I|g__Hungatella.s__Hungatella_hathewayi',
#  'ARGSYNBSUB-PWY: L-arginine biosynthesis II (acetyl cycle)|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-7222: guanosine deoxyribonucleotides de novo biosynthesis II|g__Bacteroides.s__Bacteroides_caccae',
#  'DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-5686: UMP biosynthesis I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-8178: pentose phosphate pathway (non-oxidative branch) II|g__Bacteroides.s__Bacteroides_fragilis',
#  'PWY-7790: UMP biosynthesis II|g__Alistipes.s__Alistipes_putredinis',
#  'PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Alistipes.s__Alistipes_finegoldii',
#  'PWY-7953: UDP-N-acetylmuramoyl-pentapeptide biosynthesis III (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis',
#  'NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6151: S-adenosyl-L-methionine salvage I|g__Bacteroides.s__Bacteroides_fragilis',
#  'hiPCA']

# %%
importance = pd.DataFrame(zip(list(selected.columns), clf.coef_[0]), columns = ['Features', 'Coeficient']).sort_values('Coeficient', ascending  = False)

# %%
importance.to_csv('importance4.csv', index = False)

# %%
# scaler = StandardScaler()
# for c in pathways_test.columns:
#     scaler.fit(np.array(pathways_test[c]).reshape(-1, 1))
#     pathways_test[c] = scaler.transform(np.array(pathways_test[c]).reshape(-1, 1))

# %%
pathways_test
# Out:
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# SRR5983264                                          -0.499775
# ERR209710                                           -0.499775
# SRR5947057                                          -0.197593
# SRR5983384                                          -0.409672
# SRR5935963                                           0.262733
# ...                                                       ...
# SRR5935820                                          -0.358668
# SRR5983459                                          -0.286878
# SRR5983346                                          -0.499775
# ERR210519                                           -0.499775
# SRR5935848                                           0.174649
#
# # Pathway   PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                          -0.702289
# ERR209710                                           -0.702289
# SRR5947057                                          -0.702289
# SRR5983384                                           0.433781
# SRR5935963                                           0.032212
# ...                                                       ...
# SRR5935820                                           1.532311
# SRR5983459                                          -0.702289
# SRR5983346                                           1.741208
# ERR210519                                           -0.702289
# SRR5935848                                           0.644021
#
# # Pathway   PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                          -0.678395
# ERR209710                                           -0.678395
# SRR5947057                                          -0.678395
# SRR5983384                                           0.476587
# SRR5935963                                          -0.013416
# ...                                                       ...
# SRR5935820                                           1.810326
# SRR5983459                                          -0.678395
# SRR5983346                                           1.891563
# ERR210519                                           -0.678395
# SRR5935848                                           0.572350
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                          -0.700928
# ERR209710                                           -0.700928
# SRR5947057                                          -0.700928
# SRR5983384                                           0.333120
# SRR5935963                                          -0.017728
# ...                                                       ...
# SRR5935820                                           1.891903
# SRR5983459                                          -0.700928
# SRR5983346                                           1.576171
# ERR210519                                           -0.700928
# SRR5935848                                           0.396103
#
# # Pathway   NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                          -0.676720
# ERR209710                                           -0.676720
# SRR5947057                                          -0.676720
# SRR5983384                                           0.441038
# SRR5935963                                           0.029006
# ...                                                       ...
# SRR5935820                                           1.735581
# SRR5983459                                          -0.676720
# SRR5983346                                           1.672287
# ERR210519                                           -0.676720
# SRR5935848                                           0.625930
#
# # Pathway   PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                          -0.707826
# ERR209710                                           -0.707826
# SRR5947057                                          -0.707826
# SRR5983384                                           0.340195
# SRR5935963                                          -0.087949
# ...                                                       ...
# SRR5935820                                           2.689571
# SRR5983459                                          -0.707826
# SRR5983346                                           1.298897
# ERR210519                                           -0.707826
# SRR5935848                                           0.820731
#
# # Pathway   UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii  \
# SRR5983264                                          -0.438920
# ERR209710                                           -0.438920
# SRR5947057                                           0.129545
# SRR5983384                                          -0.033644
# SRR5935963                                          -0.154342
# ...                                                       ...
# SRR5935820                                           0.211024
# SRR5983459                                          -0.438920
# SRR5983346                                          -0.438920
# ERR210519                                           -0.438920
# SRR5935848                                          -0.242687
#
# # Pathway   PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis  \
# SRR5983264                                          -0.696985
# ERR209710                                           -0.696985
# SRR5947057                                          -0.696985
# SRR5983384                                           0.283163
# SRR5935963                                           0.034053
# ...                                                       ...
# SRR5935820                                           1.434491
# SRR5983459                                          -0.696985
# SRR5983346                                           1.659310
# ERR210519                                           -0.696985
# SRR5935848                                           0.554090
#
# # Pathway   UNINTEGRATED|g__Hungatella.s__Hungatella_hathewayi     hiPCA
# SRR5983264                                          -0.218844  -0.633211
# ERR209710                                            1.094878   1.515895
# SRR5947057                                          -0.218844  -0.545887
# SRR5983384                                          -0.218844  -0.330255
# SRR5935963                                          -0.218844  -0.706646
# ...                                                       ...        ...
# SRR5935820                                          -0.218844  -0.254922
# SRR5983459                                           5.000349   1.870884
# SRR5983346                                          -0.218844  -0.071019
# ERR210519                                           -0.218844  -0.633211
# SRR5935848                                           0.094416  -0.210059
#
# [101 rows x 10 columns]

# %%
pred = clf.predict(pathways_test)
balanced_accuracy_score(y_test, pred)
# Out:
# 0.810243328100471

# %%
clf = RandomForestClassifier(max_depth=10, min_samples_leaf=3, random_state=0)
clf.fit(selected, y_train)
pred = clf.predict(pathways_test)
balanced_accuracy_score(y_test, pred)
# Out:
# 0.8402668759811617

# %%
selected
# Out:
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale  \
# ERR209799                                            0.000029
# SRR5983354                                           0.000013
# SRR5946648                                           0.000000
# ERR209854                                            0.000001
# SRR5935795                                           0.000017
# ...                                                       ...
# SRR5935770                                           0.000030
# SRR5935891                                           0.000000
# SRR5946762                                           0.000002
# SRR5947012                                           0.000004
# SRR5935823                                           0.000000
#
# # Pathway   PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000011
# SRR5983354                                           0.000026
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000037
# SRR5935823                                           0.000000
#
# # Pathway   PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000010
# SRR5983354                                           0.000021
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000028
# SRR5935823                                           0.000000
#
# # Pathway   DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000009
# SRR5983354                                           0.000025
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000030
# SRR5935823                                           0.000000
#
# # Pathway   NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000022
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000030
# SRR5935823                                           0.000000
#
# # Pathway   PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000010
# SRR5983354                                           0.000032
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000038
# SRR5935823                                           0.000000
#
# # Pathway   UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii  \
# ERR209799                                            0.000000
# SRR5983354                                           0.001581
# SRR5946648                                           0.000000
# ERR209854                                            0.000702
# SRR5935795                                           0.000447
# ...                                                       ...
# SRR5935770                                           0.003341
# SRR5935891                                           0.000000
# SRR5946762                                           0.000762
# SRR5947012                                           0.001963
# SRR5935823                                           0.000000
#
# # Pathway   PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000010
# SRR5983354                                           0.000023
# SRR5946648                                           0.000000
# ERR209854                                            0.000007
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000035
# SRR5935823                                           0.000000
#
# # Pathway   UNINTEGRATED|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000000
# SRR5946648                                           0.000000
# ERR209854                                            0.000000
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000000
# SRR5935823                                           0.003228
#
# # Pathway   PWY-7851: coenzyme A biosynthesis II (eukaryotic)|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000008
# SRR5983354                                           0.000020
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000027
# SRR5935823                                           0.000000
#
# # Pathway   ...  \
# ERR209799   ...
# SRR5983354  ...
# SRR5946648  ...
# ERR209854   ...
# SRR5935795  ...
# ...         ...
# SRR5935770  ...
# SRR5935891  ...
# SRR5946762  ...
# SRR5947012  ...
# SRR5935823  ...
#
# # Pathway   PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000022
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000029
# SRR5935823                                           0.000000
#
# # Pathway   GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii  \
# ERR209799                                            0.000041
# SRR5983354                                           0.000000
# SRR5946648                                           0.000007
# ERR209854                                            0.000025
# SRR5935795                                           0.000005
# ...                                                       ...
# SRR5935770                                           0.000077
# SRR5935891                                           0.000000
# SRR5946762                                           0.000006
# SRR5947012                                           0.000010
# SRR5935823                                           0.000033
#
# # Pathway   PWY-5695: inosine 5'-phosphate degradation|g__Alistipes.s__Alistipes_finegoldii  \
# ERR209799                                        0.000000e+00
# SRR5983354                                       5.285640e-06
# SRR5946648                                       0.000000e+00
# ERR209854                                        1.685320e-06
# SRR5935795                                       7.899730e-07
# ...                                                       ...
# SRR5935770                                       5.657960e-06
# SRR5935891                                       0.000000e+00
# SRR5946762                                       5.760000e-06
# SRR5947012                                       3.882740e-06
# SRR5935823                                       0.000000e+00
#
# # Pathway   ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000000
# SRR5946648                                           0.000000
# ERR209854                                            0.000000
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000000
# SRR5935823                                           0.000003
#
# # Pathway   PWY-6317: D-galactose degradation I (Leloir pathway)|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                                 0.0
# SRR5983354                                                0.0
# SRR5946648                                                0.0
# ERR209854                                                 0.0
# SRR5935795                                                0.0
# ...                                                       ...
# SRR5935770                                                0.0
# SRR5935891                                                0.0
# SRR5946762                                                0.0
# SRR5947012                                                0.0
# SRR5935823                                                0.0
#
# # Pathway   PWY-6700: queuosine biosynthesis I (de novo)|g__Parabacteroides.s__Parabacteroides_merdae  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000005
# SRR5946648                                           0.000000
# ERR209854                                            0.000002
# SRR5935795                                           0.000018
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000000
# SRR5935823                                           0.000000
#
# # Pathway   PWY-7791: UMP biosynthesis III|g__Alistipes.s__Alistipes_putredinis  \
# ERR209799                                            0.000011
# SRR5983354                                           0.000024
# SRR5946648                                           0.000000
# ERR209854                                            0.000006
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000037
# SRR5935823                                           0.000000
#
# # Pathway   PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Flavonifractor.s__Flavonifractor_plautii  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000000
# SRR5946648                                           0.000004
# ERR209854                                            0.000000
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000000
# SRR5935823                                           0.000000
#
# # Pathway   PWY-5667: CDP-diacylglycerol biosynthesis I|g__Hungatella.s__Hungatella_hathewayi  \
# ERR209799                                            0.000000
# SRR5983354                                           0.000000
# SRR5946648                                           0.000000
# ERR209854                                            0.000000
# SRR5935795                                           0.000000
# ...                                                       ...
# SRR5935770                                           0.000000
# SRR5935891                                           0.000000
# SRR5946762                                           0.000000
# SRR5947012                                           0.000000
# SRR5935823                                           0.000002
#
# # Pathway      hiPCA
# ERR209799  -0.459553
# SRR5983354 -0.666178
# SRR5946648 -0.617286
# ERR209854  -0.295685
# SRR5935795 -0.238637
# ...              ...
# SRR5935770 -1.092159
# SRR5935891  1.644987
# SRR5946762 -0.365656
# SRR5947012 -0.387735
# SRR5935823  0.982385
#
# [401 rows x 40 columns]

# %%
list(pd.DataFrame(zip(selected.columns, clf.feature_importances_)).sort_values(1, ascending = False)[::][0])
# Out:
# ['hiPCA',
#  'UNINTEGRATED|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-5130: 2-oxobutanoate degradation I|g__Alistipes.s__Alistipes_putredinis',
#  "PWY-6124: inosine-5'-phosphate biosynthesis II|g__Alistipes.s__Alistipes_putredinis",
#  'PWY-6609: adenine and adenosine salvage III|g__Alistipes.s__Alistipes_putredinis',
#  'UNINTEGRATED|g__Alistipes.s__Alistipes_onderdonkii',
#  'DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis',
#  'UNINTEGRATED|g__Hungatella.s__Hungatella_hathewayi',
#  'UNINTEGRATED|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-7851: coenzyme A biosynthesis II (eukaryotic)|g__Alistipes.s__Alistipes_putredinis',
#  'TRNA-CHARGING-PWY: tRNA charging|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis',
#  'PANTOSYN-PWY: superpathway of coenzyme A biosynthesis I (bacteria)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'PWY-6122: 5-aminoimidazole ribonucleotide biosynthesis II|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6700: queuosine biosynthesis I (de novo)|g__Parabacteroides.s__Parabacteroides_merdae',
#  'COA-PWY: coenzyme A biosynthesis I (prokaryotic)|g__Alistipes.s__Alistipes_finegoldii',
#  'UNINTEGRATED|g__Klebsiella.s__Klebsiella_oxytoca',
#  'PWY-6609: adenine and adenosine salvage III|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale',
#  'GALACTUROCAT-PWY: D-galacturonate degradation I|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  "PWY-5695: inosine 5'-phosphate degradation|g__Alistipes.s__Alistipes_finegoldii",
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_onderdonkii',
#  "PWY-7234: inosine-5'-phosphate biosynthesis III|g__Alistipes.s__Alistipes_putredinis",
#  'GLUCUROCAT-PWY: superpathway of &beta;-D-glucuronosides degradation|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'PWY-7242: D-fructuronate degradation|g__Faecalibacterium.s__Faecalibacterium_prausnitzii',
#  'CALVIN-PWY: Calvin-Benson-Bassham cycle|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6122: 5-aminoimidazole ribonucleotide biosynthesis II|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6387: UDP-N-acetylmuramoyl-pentapeptide biosynthesis I (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6121: 5-aminoimidazole ribonucleotide biosynthesis I|g__Alistipes.s__Alistipes_finegoldii',
#  'NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-7977: L-methionine biosynthesis IV|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-6277: superpathway of 5-aminoimidazole ribonucleotide biosynthesis|g__Flavonifractor.s__Flavonifractor_plautii',
#  '1CMET2-PWY: folate transformations III (E. coli)|g__Alistipes.s__Alistipes_putredinis',
#  "PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis",
#  'ILEUSYN-PWY: L-isoleucine biosynthesis I (from threonine)|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-6317: D-galactose degradation I (Leloir pathway)|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-7953: UDP-N-acetylmuramoyl-pentapeptide biosynthesis III (meso-diaminopimelate containing)|g__Alistipes.s__Alistipes_putredinis',
#  'PWY-5667: CDP-diacylglycerol biosynthesis I|g__Hungatella.s__Hungatella_hathewayi',
#  'PWY-7791: UMP biosynthesis III|g__Alistipes.s__Alistipes_putredinis']

# %%
predp = clf.predict_proba(X_test)
# Out:
# C:\Users\rafap\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Abiotrophia_sp_HMSC24B09
# - Achromobacter_SGB14223
# - Acidaminococcus_SGB42794
# - Acidaminococcus_SGB5735
# - Acidaminococcus_fermentans
# - ...
# Feature names seen at fit time, yet now missing:
# - DTDPRHAMSYN-PWY: dTDP-&beta;-L-rhamnose biosynthesis|g__Alistipes.s__Alistipes_putredinis
# - NONMEVIPP-PWY: methylerythritol phosphate pathway I|g__Alistipes.s__Alistipes_putredinis
# - PWY-3841: folate transformations II (plants)|g__Alistipes.s__Alistipes_putredinis
# - PWY-5667: CDP-diacylglycerol biosynthesis I|g__Lachnospiraceae_unclassified.s__Eubacterium_rectale
# - PWY-6123: inosine-5'-phosphate biosynthesis I|g__Alistipes.s__Alistipes_putredinis
# - ...
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [221], in <cell line: 1>()
# ----> 1 predp = clf.predict_proba(X_test)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:1311, in LogisticRegression.predict_proba(self, X)
#    1306 ovr = self.multi_class in ["ovr", "warn"] or (
#    1307     self.multi_class == "auto"
#    1308     and (self.classes_.size <= 2 or self.solver == "liblinear")
#    1309 )
#    1310 if ovr:
# -> 1311     return super()._predict_proba_lr(X)
#    1312 else:
#    1313     decision = self.decision_function(X)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:461, in LinearClassifierMixin._predict_proba_lr(self, X)
#     454 def _predict_proba_lr(self, X):
#     455     """Probability estimation for OvR logistic regression.
#     456
#     457     Positive class probabilities are computed as
#     458     1. / (1. + np.exp(-self.decision_function(X)));
#     459     multiclass is handled by normalizing that over all classes.
#     460     """
# --> 461     prob = self.decision_function(X)
#     462     expit(prob, out=prob)
#     463     if prob.ndim == 1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_base.py:429, in LinearClassifierMixin.decision_function(self, X)
#     409 """
#     410 Predict confidence scores for samples.
#     411
#    (...)
#     425     this class would be predicted.
#     426 """
#     427 check_is_fitted(self)
# --> 429 X = self._validate_data(X, accept_sparse="csr", reset=False)
#     430 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     431 return scores.ravel() if scores.shape[1] == 1 else scores
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:600, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
# --> 600     self._check_n_features(X, reset=reset)
#     602 return out
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 2115 features, but LogisticRegression is expecting 10 features as input.

# %%
p = []
for item in X_test.index:
    p.append(metadata[metadata['SampleID'] == item]['Diagnosis'].iloc[0])

# %%
pd.DataFrame(zip(X_test.index, [x[1] for x in predp], pred, p), columns = ['SampleID', 'DE-hiPCA_Pathways-LogReg', 'Prediction', 'Diagnosis']).to_csv('results.csv', index = False)

# %%
unhealthy_functions
